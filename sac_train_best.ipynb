# %%
import gym

from stable_baselines3 import SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor

# %%
train_env = make_vec_env("LunarLanderContinuous-v2", n_envs=16)
eval_env = Monitor(gym.make("LunarLanderContinuous-v2"))
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./logs/continuous/sac",
    log_path="./logs/continuous/sac",
    eval_freq=1000,
    n_eval_episodes=10,
    deterministic=True,
    render=False,
)

# %%
model = SAC.load("logs/continuous/sac/best_model_286", env=train_env)

# %%
model.learn(total_timesteps=int(1e6), callback=eval_callback)
# Out:
# Logging to ./runs/sac_lunar_tensorboard/SAC_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84       |
# |    ep_rew_mean     | -260     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 5047     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1392     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89       |
# |    ep_rew_mean     | -234     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 5000     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.2     |
# |    ep_rew_mean     | -275     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 5024     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1824     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -243     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 5051     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -231     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 5178     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.5     |
# |    ep_rew_mean     | -221     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 5126     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3184     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.2     |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 5136     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3488     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -214     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 5153     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3824     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.7     |
# |    ep_rew_mean     | -214     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 5156     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 4624     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 5041     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 4960     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -205     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 4985     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5184     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -204     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 4932     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5648     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -212     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 4750     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6432     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -221     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 4683     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6704     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -224     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 4665     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6880     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -220     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 4683     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7424     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -219     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 4656     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 8096     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -215     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 4643     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 8560     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -212     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 4629     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 8880     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 4614     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9248     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 4604     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9808     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 3809     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 10336    |
# | train/             |          |
# |    actor_loss      | -36.9    |
# |    critic_loss     | 46.9     |
# |    ent_coef        | 0.0278   |
# |    ent_coef_loss   | 14.5     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211014   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 2368     |
# |    time_elapsed    | 4        |
# |    total_timesteps | 11744    |
# | train/             |          |
# |    actor_loss      | -46.7    |
# |    critic_loss     | 120      |
# |    ent_coef        | 0.0365   |
# |    ent_coef_loss   | 13.4     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211102   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -181     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 2090     |
# |    time_elapsed    | 5        |
# |    total_timesteps | 12320    |
# | train/             |          |
# |    actor_loss      | -51.6    |
# |    critic_loss     | 25.2     |
# |    ent_coef        | 0.0393   |
# |    ent_coef_loss   | 11.1     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211138   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | -150     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 1775     |
# |    time_elapsed    | 7        |
# |    total_timesteps | 13200    |
# | train/             |          |
# |    actor_loss      | -67      |
# |    critic_loss     | 17.5     |
# |    ent_coef        | 0.0426   |
# |    ent_coef_loss   | 11       |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211193   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | -141     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 1705     |
# |    time_elapsed    | 7        |
# |    total_timesteps | 13472    |
# | train/             |          |
# |    actor_loss      | -66      |
# |    critic_loss     | 19.7     |
# |    ent_coef        | 0.0437   |
# |    ent_coef_loss   | 8.86     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211210   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | -124     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 1630     |
# |    time_elapsed    | 8        |
# |    total_timesteps | 13888    |
# | train/             |          |
# |    actor_loss      | -56.9    |
# |    critic_loss     | 73.5     |
# |    ent_coef        | 0.0452   |
# |    ent_coef_loss   | 8.87     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211236   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | -104     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 1480     |
# |    time_elapsed    | 10       |
# |    total_timesteps | 14832    |
# | train/             |          |
# |    actor_loss      | -65.8    |
# |    critic_loss     | 15       |
# |    ent_coef        | 0.0483   |
# |    ent_coef_loss   | 5.89     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211295   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 126      |
# |    ep_rew_mean     | -91.4    |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 1369     |
# |    time_elapsed    | 11       |
# |    total_timesteps | 15744    |
# | train/             |          |
# |    actor_loss      | -58.9    |
# |    critic_loss     | 17.7     |
# |    ent_coef        | 0.0508   |
# |    ent_coef_loss   | 5.75     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211352   |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=262.23 +/- 80.69
# Episode length: 179.70 +/- 31.09
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 180      |
# |    mean_reward     | 262      |
# | time/              |          |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -66.7    |
# |    critic_loss     | 42.6     |
# |    ent_coef        | 0.0514   |
# |    ent_coef_loss   | 6.43     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211368   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | -73.2    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 1191     |
# |    time_elapsed    | 13       |
# |    total_timesteps | 16272    |
# | train/             |          |
# |    actor_loss      | -63.7    |
# |    critic_loss     | 37.8     |
# |    ent_coef        | 0.0521   |
# |    ent_coef_loss   | 4.66     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211385   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | -55.3    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 1158     |
# |    time_elapsed    | 14       |
# |    total_timesteps | 16720    |
# | train/             |          |
# |    actor_loss      | -60.4    |
# |    critic_loss     | 21.4     |
# |    ent_coef        | 0.0531   |
# |    ent_coef_loss   | 5.66     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211413   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 137      |
# |    ep_rew_mean     | -36.1    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 1090     |
# |    time_elapsed    | 16       |
# |    total_timesteps | 17952    |
# | train/             |          |
# |    actor_loss      | -70.6    |
# |    critic_loss     | 31.9     |
# |    ent_coef        | 0.0557   |
# |    ent_coef_loss   | 3.73     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211490   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | -17.3    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 1054     |
# |    time_elapsed    | 17       |
# |    total_timesteps | 18816    |
# | train/             |          |
# |    actor_loss      | -65      |
# |    critic_loss     | 17.8     |
# |    ent_coef        | 0.0573   |
# |    ent_coef_loss   | 3.41     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211544   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | 2.25     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 1050     |
# |    time_elapsed    | 18       |
# |    total_timesteps | 18928    |
# | train/             |          |
# |    actor_loss      | -74      |
# |    critic_loss     | 9.93     |
# |    ent_coef        | 0.0574   |
# |    ent_coef_loss   | 3.18     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211551   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 146      |
# |    ep_rew_mean     | 23.6     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 1015     |
# |    time_elapsed    | 19       |
# |    total_timesteps | 20064    |
# | train/             |          |
# |    actor_loss      | -78.7    |
# |    critic_loss     | 17.1     |
# |    ent_coef        | 0.0595   |
# |    ent_coef_loss   | 1.87     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211622   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 149      |
# |    ep_rew_mean     | 37.8     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 987      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 20944    |
# | train/             |          |
# |    actor_loss      | -78.3    |
# |    critic_loss     | 15.1     |
# |    ent_coef        | 0.0609   |
# |    ent_coef_loss   | 3.04     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211677   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 151      |
# |    ep_rew_mean     | 57.3     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 976      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 21376    |
# | train/             |          |
# |    actor_loss      | -76.2    |
# |    critic_loss     | 15.6     |
# |    ent_coef        | 0.0616   |
# |    ent_coef_loss   | 2.57     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211704   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 155      |
# |    ep_rew_mean     | 81.7     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 956      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 22160    |
# | train/             |          |
# |    actor_loss      | -78.9    |
# |    critic_loss     | 19.9     |
# |    ent_coef        | 0.0627   |
# |    ent_coef_loss   | 2.99     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211753   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 157      |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 946      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 22560    |
# | train/             |          |
# |    actor_loss      | -75.6    |
# |    critic_loss     | 13.9     |
# |    ent_coef        | 0.0632   |
# |    ent_coef_loss   | 2.32     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211778   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 160      |
# |    ep_rew_mean     | 129      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 924      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 23504    |
# | train/             |          |
# |    actor_loss      | -82      |
# |    critic_loss     | 6.89     |
# |    ent_coef        | 0.0644   |
# |    ent_coef_loss   | 1.39     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211837   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 898      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 24976    |
# | train/             |          |
# |    actor_loss      | -72.6    |
# |    critic_loss     | 7.98     |
# |    ent_coef        | 0.0661   |
# |    ent_coef_loss   | 1.7      |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211929   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | 171      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 897      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 25024    |
# | train/             |          |
# |    actor_loss      | -79.1    |
# |    critic_loss     | 22.7     |
# |    ent_coef        | 0.0662   |
# |    ent_coef_loss   | 1.36     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211932   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 169      |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 895      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 25232    |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 75.5     |
# |    ent_coef        | 0.0664   |
# |    ent_coef_loss   | 1.63     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 211945   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 172      |
# |    ep_rew_mean     | 202      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 883      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 26224    |
# | train/             |          |
# |    actor_loss      | -77.4    |
# |    critic_loss     | 23.1     |
# |    ent_coef        | 0.0673   |
# |    ent_coef_loss   | 1.15     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212007   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 174      |
# |    ep_rew_mean     | 219      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 868      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 27568    |
# | train/             |          |
# |    actor_loss      | -76.8    |
# |    critic_loss     | 9.24     |
# |    ent_coef        | 0.0685   |
# |    ent_coef_loss   | 1.34     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212091   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 177      |
# |    ep_rew_mean     | 238      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 866      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 27776    |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 24.2     |
# |    ent_coef        | 0.0687   |
# |    ent_coef_loss   | 1.49     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212104   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 258      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 863      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 28016    |
# | train/             |          |
# |    actor_loss      | -85.7    |
# |    critic_loss     | 17.4     |
# |    ent_coef        | 0.0689   |
# |    ent_coef_loss   | 1.28     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212119   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 182      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 852      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 29248    |
# | train/             |          |
# |    actor_loss      | -79.2    |
# |    critic_loss     | 16.7     |
# |    ent_coef        | 0.07     |
# |    ent_coef_loss   | 1.67     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212196   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 182      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 842      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 30320    |
# | train/             |          |
# |    actor_loss      | -89.2    |
# |    critic_loss     | 8.21     |
# |    ent_coef        | 0.0707   |
# |    ent_coef_loss   | 1.26     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212263   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 182      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 836      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 30912    |
# | train/             |          |
# |    actor_loss      | -82.1    |
# |    critic_loss     | 46.2     |
# |    ent_coef        | 0.0713   |
# |    ent_coef_loss   | 1.05     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212300   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 831      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 31600    |
# | train/             |          |
# |    actor_loss      | -85.7    |
# |    critic_loss     | 4.44     |
# |    ent_coef        | 0.0718   |
# |    ent_coef_loss   | -0.063   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212343   |
# ---------------------------------
# Eval num_timesteps=32000, episode_reward=284.47 +/- 9.94
# Episode length: 181.80 +/- 23.90
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 182      |
# |    mean_reward     | 284      |
# | time/              |          |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -85      |
# |    critic_loss     | 3.77     |
# |    ent_coef        | 0.0721   |
# |    ent_coef_loss   | 0.354    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212368   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 804      |
# |    time_elapsed    | 39       |
# |    total_timesteps | 32032    |
# | train/             |          |
# |    actor_loss      | -88.2    |
# |    critic_loss     | 2.82     |
# |    ent_coef        | 0.0721   |
# |    ent_coef_loss   | 0.761    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212370   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 181      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 797      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 32992    |
# | train/             |          |
# |    actor_loss      | -91.1    |
# |    critic_loss     | 10.7     |
# |    ent_coef        | 0.0726   |
# |    ent_coef_loss   | -0.375   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212430   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 181      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 792      |
# |    time_elapsed    | 42       |
# |    total_timesteps | 33728    |
# | train/             |          |
# |    actor_loss      | -89      |
# |    critic_loss     | 21.1     |
# |    ent_coef        | 0.0728   |
# |    ent_coef_loss   | 0.439    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212476   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 181      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 789      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 34448    |
# | train/             |          |
# |    actor_loss      | -93.6    |
# |    critic_loss     | 13.2     |
# |    ent_coef        | 0.0732   |
# |    ent_coef_loss   | 0.498    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212521   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 181      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 787      |
# |    time_elapsed    | 44       |
# |    total_timesteps | 34832    |
# | train/             |          |
# |    actor_loss      | -86      |
# |    critic_loss     | 9.3      |
# |    ent_coef        | 0.0734   |
# |    ent_coef_loss   | 0.115    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212545   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 179      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 784      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 35632    |
# | train/             |          |
# |    actor_loss      | -86.8    |
# |    critic_loss     | 11.4     |
# |    ent_coef        | 0.0737   |
# |    ent_coef_loss   | 0.0235   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212595   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 179      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 781      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 36288    |
# | train/             |          |
# |    actor_loss      | -93.7    |
# |    critic_loss     | 2.92     |
# |    ent_coef        | 0.074    |
# |    ent_coef_loss   | 0.578    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212636   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 178      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 779      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 36960    |
# | train/             |          |
# |    actor_loss      | -92.3    |
# |    critic_loss     | 9.79     |
# |    ent_coef        | 0.0742   |
# |    ent_coef_loss   | -0.27    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212678   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 177      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 776      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 37568    |
# | train/             |          |
# |    actor_loss      | -89.5    |
# |    critic_loss     | 9.62     |
# |    ent_coef        | 0.0745   |
# |    ent_coef_loss   | 0.276    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212716   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 177      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 775      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 38048    |
# | train/             |          |
# |    actor_loss      | -91      |
# |    critic_loss     | 9.75     |
# |    ent_coef        | 0.0745   |
# |    ent_coef_loss   | 0.234    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212746   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 177      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 770      |
# |    time_elapsed    | 50       |
# |    total_timesteps | 39296    |
# | train/             |          |
# |    actor_loss      | -86.5    |
# |    critic_loss     | 10       |
# |    ent_coef        | 0.0746   |
# |    ent_coef_loss   | 0.276    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212824   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 176      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 770      |
# |    time_elapsed    | 51       |
# |    total_timesteps | 39600    |
# | train/             |          |
# |    actor_loss      | -84.1    |
# |    critic_loss     | 8.78     |
# |    ent_coef        | 0.0746   |
# |    ent_coef_loss   | 0.866    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212843   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 176      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 768      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 40192    |
# | train/             |          |
# |    actor_loss      | -89      |
# |    critic_loss     | 26.4     |
# |    ent_coef        | 0.0744   |
# |    ent_coef_loss   | -0.095   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212880   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 176      |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 765      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 41136    |
# | train/             |          |
# |    actor_loss      | -95      |
# |    critic_loss     | 3.12     |
# |    ent_coef        | 0.0741   |
# |    ent_coef_loss   | -0.303   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212939   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 176      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 761      |
# |    time_elapsed    | 54       |
# |    total_timesteps | 41728    |
# | train/             |          |
# |    actor_loss      | -91.7    |
# |    critic_loss     | 9.11     |
# |    ent_coef        | 0.0741   |
# |    ent_coef_loss   | -0.205   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 212976   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 176      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 759      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 42400    |
# | train/             |          |
# |    actor_loss      | -89.5    |
# |    critic_loss     | 7.59     |
# |    ent_coef        | 0.0739   |
# |    ent_coef_loss   | -0.596   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213018   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 175      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 757      |
# |    time_elapsed    | 56       |
# |    total_timesteps | 43088    |
# | train/             |          |
# |    actor_loss      | -90.7    |
# |    critic_loss     | 38.3     |
# |    ent_coef        | 0.0738   |
# |    ent_coef_loss   | 0.0578   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213061   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 176      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 756      |
# |    time_elapsed    | 57       |
# |    total_timesteps | 43696    |
# | train/             |          |
# |    actor_loss      | -92.2    |
# |    critic_loss     | 11.5     |
# |    ent_coef        | 0.0736   |
# |    ent_coef_loss   | -0.398   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213099   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 174      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 754      |
# |    time_elapsed    | 58       |
# |    total_timesteps | 44464    |
# | train/             |          |
# |    actor_loss      | -89.5    |
# |    critic_loss     | 7.44     |
# |    ent_coef        | 0.0731   |
# |    ent_coef_loss   | -0.0415  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213147   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 174      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 753      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 44944    |
# | train/             |          |
# |    actor_loss      | -93.4    |
# |    critic_loss     | 3.31     |
# |    ent_coef        | 0.073    |
# |    ent_coef_loss   | -0.351   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213177   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 175      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 751      |
# |    time_elapsed    | 61       |
# |    total_timesteps | 45856    |
# | train/             |          |
# |    actor_loss      | -92.2    |
# |    critic_loss     | 2.13     |
# |    ent_coef        | 0.0728   |
# |    ent_coef_loss   | 0.466    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213234   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 174      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 749      |
# |    time_elapsed    | 61       |
# |    total_timesteps | 46368    |
# | train/             |          |
# |    actor_loss      | -97      |
# |    critic_loss     | 5.7      |
# |    ent_coef        | 0.0727   |
# |    ent_coef_loss   | -0.236   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213266   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 173      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 748      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 47312    |
# | train/             |          |
# |    actor_loss      | -90.2    |
# |    critic_loss     | 19       |
# |    ent_coef        | 0.0724   |
# |    ent_coef_loss   | 0.367    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213325   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 173      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 746      |
# |    time_elapsed    | 64       |
# |    total_timesteps | 47792    |
# | train/             |          |
# |    actor_loss      | -92.5    |
# |    critic_loss     | 2.72     |
# |    ent_coef        | 0.0722   |
# |    ent_coef_loss   | -0.941   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213355   |
# ---------------------------------
# Eval num_timesteps=48000, episode_reward=280.03 +/- 17.62
# Episode length: 173.00 +/- 16.64
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 173      |
# |    mean_reward     | 280      |
# | time/              |          |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -93      |
# |    critic_loss     | 2.43     |
# |    ent_coef        | 0.072    |
# |    ent_coef_loss   | -0.432   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213368   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 731      |
# |    time_elapsed    | 66       |
# |    total_timesteps | 48560    |
# | train/             |          |
# |    actor_loss      | -91.1    |
# |    critic_loss     | 2.32     |
# |    ent_coef        | 0.0718   |
# |    ent_coef_loss   | -0.0466  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213403   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 169      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 730      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 49344    |
# | train/             |          |
# |    actor_loss      | -93.2    |
# |    critic_loss     | 5.4      |
# |    ent_coef        | 0.0715   |
# |    ent_coef_loss   | -0.331   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213452   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 729      |
# |    time_elapsed    | 68       |
# |    total_timesteps | 50016    |
# | train/             |          |
# |    actor_loss      | -92.4    |
# |    critic_loss     | 6.41     |
# |    ent_coef        | 0.0712   |
# |    ent_coef_loss   | 0.436    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213494   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 728      |
# |    time_elapsed    | 69       |
# |    total_timesteps | 50640    |
# | train/             |          |
# |    actor_loss      | -94.1    |
# |    critic_loss     | 4.81     |
# |    ent_coef        | 0.0706   |
# |    ent_coef_loss   | -1.2     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213533   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 727      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 51408    |
# | train/             |          |
# |    actor_loss      | -95.9    |
# |    critic_loss     | 29.1     |
# |    ent_coef        | 0.0705   |
# |    ent_coef_loss   | -0.55    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213581   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 726      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 52032    |
# | train/             |          |
# |    actor_loss      | -94.4    |
# |    critic_loss     | 4.45     |
# |    ent_coef        | 0.0702   |
# |    ent_coef_loss   | -0.955   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213620   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 725      |
# |    time_elapsed    | 72       |
# |    total_timesteps | 52672    |
# | train/             |          |
# |    actor_loss      | -96.5    |
# |    critic_loss     | 5.71     |
# |    ent_coef        | 0.0699   |
# |    ent_coef_loss   | -0.74    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213660   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 723      |
# |    time_elapsed    | 74       |
# |    total_timesteps | 53616    |
# | train/             |          |
# |    actor_loss      | -88.5    |
# |    critic_loss     | 2.71     |
# |    ent_coef        | 0.0691   |
# |    ent_coef_loss   | -0.611   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213719   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 723      |
# |    time_elapsed    | 74       |
# |    total_timesteps | 53856    |
# | train/             |          |
# |    actor_loss      | -90.9    |
# |    critic_loss     | 5.47     |
# |    ent_coef        | 0.0689   |
# |    ent_coef_loss   | 0.506    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213734   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 722      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 54480    |
# | train/             |          |
# |    actor_loss      | -97.8    |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.0689   |
# |    ent_coef_loss   | -0.301   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213773   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 721      |
# |    time_elapsed    | 76       |
# |    total_timesteps | 55088    |
# | train/             |          |
# |    actor_loss      | -90.5    |
# |    critic_loss     | 6.98     |
# |    ent_coef        | 0.0684   |
# |    ent_coef_loss   | -0.409   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213811   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 720      |
# |    time_elapsed    | 77       |
# |    total_timesteps | 56176    |
# | train/             |          |
# |    actor_loss      | -92      |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.0675   |
# |    ent_coef_loss   | -0.106   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213879   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 719      |
# |    time_elapsed    | 78       |
# |    total_timesteps | 56672    |
# | train/             |          |
# |    actor_loss      | -91.2    |
# |    critic_loss     | 7.93     |
# |    ent_coef        | 0.067    |
# |    ent_coef_loss   | -0.682   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 213910   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 718      |
# |    time_elapsed    | 80       |
# |    total_timesteps | 57536    |
# | train/             |          |
# ...
# |    fps             | 596      |
# |    time_elapsed    | 1647     |
# |    total_timesteps | 982912   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 0.542    |
# |    ent_coef        | 0.0198   |
# |    ent_coef_loss   | -0.572   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 271800   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 5764     |
# |    fps             | 596      |
# |    time_elapsed    | 1648     |
# |    total_timesteps | 983600   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 4.68     |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | -0.254   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 271843   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5768     |
# |    fps             | 596      |
# |    time_elapsed    | 1650     |
# |    total_timesteps | 984320   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 2.73     |
# |    ent_coef        | 0.0196   |
# |    ent_coef_loss   | 0.403    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 271888   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 5772     |
# |    fps             | 596      |
# |    time_elapsed    | 1651     |
# |    total_timesteps | 985040   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 3.54     |
# |    ent_coef        | 0.0197   |
# |    ent_coef_loss   | -0.353   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 271933   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 5776     |
# |    fps             | 596      |
# |    time_elapsed    | 1652     |
# |    total_timesteps | 985536   |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 6.26     |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | -1.05    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 271964   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 161      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 5780     |
# |    fps             | 596      |
# |    time_elapsed    | 1653     |
# |    total_timesteps | 986368   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 2.68     |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | -0.294   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272016   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 5784     |
# |    fps             | 596      |
# |    time_elapsed    | 1654     |
# |    total_timesteps | 986864   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 4.49     |
# |    ent_coef        | 0.0198   |
# |    ent_coef_loss   | 1.17     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272047   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5788     |
# |    fps             | 596      |
# |    time_elapsed    | 1655     |
# |    total_timesteps | 987696   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 2.25     |
# |    ent_coef        | 0.0202   |
# |    ent_coef_loss   | 0.0163   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272099   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 5792     |
# |    fps             | 596      |
# |    time_elapsed    | 1656     |
# |    total_timesteps | 988144   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 0.923    |
# |    ent_coef        | 0.0206   |
# |    ent_coef_loss   | 0.386    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272127   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5796     |
# |    fps             | 596      |
# |    time_elapsed    | 1657     |
# |    total_timesteps | 989072   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 4.75     |
# |    ent_coef        | 0.0207   |
# |    ent_coef_loss   | -0.758   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272185   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5800     |
# |    fps             | 596      |
# |    time_elapsed    | 1658     |
# |    total_timesteps | 989552   |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 3        |
# |    ent_coef        | 0.0203   |
# |    ent_coef_loss   | 0.152    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272215   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5804     |
# |    fps             | 596      |
# |    time_elapsed    | 1659     |
# |    total_timesteps | 990288   |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 0.538    |
# |    ent_coef        | 0.0207   |
# |    ent_coef_loss   | -0.0385  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272261   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5808     |
# |    fps             | 596      |
# |    time_elapsed    | 1660     |
# |    total_timesteps | 990640   |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 4.62     |
# |    ent_coef        | 0.0207   |
# |    ent_coef_loss   | -0.155   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272283   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5812     |
# |    fps             | 596      |
# |    time_elapsed    | 1661     |
# |    total_timesteps | 991328   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 5.04     |
# |    ent_coef        | 0.0208   |
# |    ent_coef_loss   | 0.325    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272326   |
# ---------------------------------
# Eval num_timesteps=992000, episode_reward=288.75 +/- 18.00
# Episode length: 163.90 +/- 16.51
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 164      |
# |    mean_reward     | 289      |
# | time/              |          |
# |    total_timesteps | 992000   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 0.584    |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | -0.482   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272368   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5816     |
# |    fps             | 596      |
# |    time_elapsed    | 1664     |
# |    total_timesteps | 992368   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 6.7      |
# |    ent_coef        | 0.0209   |
# |    ent_coef_loss   | -0.689   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272391   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 288      |
# | time/              |          |
# |    episodes        | 5820     |
# |    fps             | 596      |
# |    time_elapsed    | 1665     |
# |    total_timesteps | 993056   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 4.39     |
# |    ent_coef        | 0.0207   |
# |    ent_coef_loss   | -0.355   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272434   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 288      |
# | time/              |          |
# |    episodes        | 5824     |
# |    fps             | 596      |
# |    time_elapsed    | 1665     |
# |    total_timesteps | 993312   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 0.491    |
# |    ent_coef        | 0.0207   |
# |    ent_coef_loss   | -0.644   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272450   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 288      |
# | time/              |          |
# |    episodes        | 5828     |
# |    fps             | 596      |
# |    time_elapsed    | 1666     |
# |    total_timesteps | 993936   |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 1.88     |
# |    ent_coef        | 0.0205   |
# |    ent_coef_loss   | -0.338   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272489   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5832     |
# |    fps             | 596      |
# |    time_elapsed    | 1668     |
# |    total_timesteps | 994816   |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 2.49     |
# |    ent_coef        | 0.0205   |
# |    ent_coef_loss   | 0.0525   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272544   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5836     |
# |    fps             | 596      |
# |    time_elapsed    | 1669     |
# |    total_timesteps | 995568   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 3.54     |
# |    ent_coef        | 0.0204   |
# |    ent_coef_loss   | -0.0694  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272591   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 5840     |
# |    fps             | 596      |
# |    time_elapsed    | 1670     |
# |    total_timesteps | 995920   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 3.28     |
# |    ent_coef        | 0.0207   |
# |    ent_coef_loss   | -0.542   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272613   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5844     |
# |    fps             | 596      |
# |    time_elapsed    | 1671     |
# |    total_timesteps | 996752   |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 1        |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | 0.174    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272665   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5848     |
# |    fps             | 596      |
# |    time_elapsed    | 1672     |
# |    total_timesteps | 997520   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 5.93     |
# |    ent_coef        | 0.0208   |
# |    ent_coef_loss   | -0.738   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272713   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5852     |
# |    fps             | 596      |
# |    time_elapsed    | 1673     |
# |    total_timesteps | 998128   |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 0.662    |
# |    ent_coef        | 0.0206   |
# |    ent_coef_loss   | -0.597   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272751   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5856     |
# |    fps             | 596      |
# |    time_elapsed    | 1674     |
# |    total_timesteps | 998656   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 1.78     |
# |    ent_coef        | 0.0205   |
# |    ent_coef_loss   | 0.435    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272784   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5860     |
# |    fps             | 596      |
# |    time_elapsed    | 1675     |
# |    total_timesteps | 999216   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 2.78     |
# |    ent_coef        | 0.0205   |
# |    ent_coef_loss   | -0.241   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272819   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5864     |
# |    fps             | 596      |
# |    time_elapsed    | 1676     |
# |    total_timesteps | 999888   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 4.87     |
# |    ent_coef        | 0.0204   |
# |    ent_coef_loss   | -0.321   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 272861   |
# ---------------------------------

# %%
model.save("data/policies/LunarLanderContinuous-v2#sac#train_best")
del model
