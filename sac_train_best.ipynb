# %%
import gym

from stable_baselines3 import SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor

# %%
train_env = make_vec_env("LunarLanderContinuous-v2", n_envs=16)
eval_env = Monitor(gym.make("LunarLanderContinuous-v2"))
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./logs/continuous/sac",
    log_path="./logs/continuous/sac",
    eval_freq=1000,
    n_eval_episodes=10,
    deterministic=True,
    render=False,
)

# %%
model = SAC.load("logs/continuous/sac/best_model", env=train_env)

# %%
model.learn(total_timesteps=int(1e6), callback=eval_callback)
# Out:
# Logging to ./runs/sac_lunar_tensorboard/SAC_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.8     |
# |    ep_rew_mean     | -155     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 4045     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1456     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.2     |
# |    ep_rew_mean     | -191     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 3973     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1536     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.2     |
# |    ep_rew_mean     | -248     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 3998     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1808     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -251     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 4062     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2352     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -235     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 3997     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2976     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.6     |
# |    ep_rew_mean     | -255     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 3934     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3376     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -257     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 3893     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3520     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -260     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 3830     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3968     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -247     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 3789     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4720     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -242     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 3776     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -237     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 3784     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5120     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -237     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 3803     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5920     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -225     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 3767     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6192     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -224     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 3702     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6496     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -232     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 3664     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7040     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -235     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 3623     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7568     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -232     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 3593     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7840     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -233     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 3595     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8512     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -234     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 3583     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9088     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | -229     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 3574     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9328     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | -233     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 3581     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9536     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -232     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 2696     |
# |    time_elapsed    | 4        |
# |    total_timesteps | 10880    |
# | train/             |          |
# |    actor_loss      | -36.3    |
# |    critic_loss     | 6.44     |
# |    ent_coef        | 0.0529   |
# |    ent_coef_loss   | 5.86     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 65926    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -211     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 1718     |
# |    time_elapsed    | 7        |
# |    total_timesteps | 12832    |
# | train/             |          |
# |    actor_loss      | -42.7    |
# |    critic_loss     | 27.9     |
# |    ent_coef        | 0.0649   |
# |    ent_coef_loss   | 2.77     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66048    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | -191     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 1508     |
# |    time_elapsed    | 9        |
# |    total_timesteps | 13808    |
# | train/             |          |
# |    actor_loss      | -45.2    |
# |    critic_loss     | 17.1     |
# |    ent_coef        | 0.0693   |
# |    ent_coef_loss   | 2.95     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66109    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 128      |
# |    ep_rew_mean     | -169     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 1389     |
# |    time_elapsed    | 10       |
# |    total_timesteps | 14544    |
# | train/             |          |
# |    actor_loss      | -52      |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.0725   |
# |    ent_coef_loss   | 1.08     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66155    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | -156     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 1345     |
# |    time_elapsed    | 11       |
# |    total_timesteps | 15072    |
# | train/             |          |
# |    actor_loss      | -43.9    |
# |    critic_loss     | 6        |
# |    ent_coef        | 0.0742   |
# |    ent_coef_loss   | 2.02     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66188    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 138      |
# |    ep_rew_mean     | -136     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 1298     |
# |    time_elapsed    | 12       |
# |    total_timesteps | 15776    |
# | train/             |          |
# |    actor_loss      | -51.4    |
# |    critic_loss     | 7.19     |
# |    ent_coef        | 0.0764   |
# |    ent_coef_loss   | 2.1      |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66232    |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=289.29 +/- 4.76
# Episode length: 273.40 +/- 101.79
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 273      |
# |    mean_reward     | 289      |
# | time/              |          |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -43.8    |
# |    critic_loss     | 9.72     |
# |    ent_coef        | 0.077    |
# |    ent_coef_loss   | 1.28     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66246    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 1063     |
# |    time_elapsed    | 15       |
# |    total_timesteps | 16816    |
# | train/             |          |
# |    actor_loss      | -52.8    |
# |    critic_loss     | 5.05     |
# |    ent_coef        | 0.0788   |
# |    ent_coef_loss   | 1.71     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66297    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | -88.9    |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 1031     |
# |    time_elapsed    | 17       |
# |    total_timesteps | 17616    |
# | train/             |          |
# |    actor_loss      | -60.9    |
# |    critic_loss     | 6.05     |
# |    ent_coef        | 0.0805   |
# |    ent_coef_loss   | 0.771    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66347    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 148      |
# |    ep_rew_mean     | -71.1    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 989      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 18624    |
# | train/             |          |
# |    actor_loss      | -57.1    |
# |    critic_loss     | 3.31     |
# |    ent_coef        | 0.0818   |
# |    ent_coef_loss   | 0.576    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66410    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 152      |
# |    ep_rew_mean     | -45.6    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 946      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 19840    |
# | train/             |          |
# |    actor_loss      | -58.8    |
# |    critic_loss     | 4.38     |
# |    ent_coef        | 0.0835   |
# |    ent_coef_loss   | 0.053    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66486    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 156      |
# |    ep_rew_mean     | -23.9    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 926      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 20496    |
# | train/             |          |
# |    actor_loss      | -63.8    |
# |    critic_loss     | 3.11     |
# |    ent_coef        | 0.0844   |
# |    ent_coef_loss   | 0.278    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66527    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 160      |
# |    ep_rew_mean     | -1.58    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 916      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 20896    |
# | train/             |          |
# |    actor_loss      | -59.7    |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.0849   |
# |    ent_coef_loss   | 1.1      |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66552    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 166      |
# |    ep_rew_mean     | 15.1     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 895      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 22336    |
# | train/             |          |
# |    actor_loss      | -61.8    |
# |    critic_loss     | 3.31     |
# |    ent_coef        | 0.0864   |
# |    ent_coef_loss   | 0.163    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66642    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | 33.5     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 876      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 23648    |
# | train/             |          |
# |    actor_loss      | -69.3    |
# |    critic_loss     | 2.38     |
# |    ent_coef        | 0.0868   |
# |    ent_coef_loss   | -0.208   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66724    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 175      |
# |    ep_rew_mean     | 51.4     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 871      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -59.4    |
# |    critic_loss     | 15.2     |
# |    ent_coef        | 0.0867   |
# |    ent_coef_loss   | 0.402    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66746    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 72.1     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 864      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 24496    |
# | train/             |          |
# |    actor_loss      | -60.8    |
# |    critic_loss     | 3.18     |
# |    ent_coef        | 0.0868   |
# |    ent_coef_loss   | 0.766    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66777    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | 85.6     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 834      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 26512    |
# | train/             |          |
# |    actor_loss      | -63.3    |
# |    critic_loss     | 12.8     |
# |    ent_coef        | 0.0862   |
# |    ent_coef_loss   | 0.217    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66903    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 189      |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 824      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 27008    |
# | train/             |          |
# |    actor_loss      | -63.9    |
# |    critic_loss     | 2.57     |
# |    ent_coef        | 0.0859   |
# |    ent_coef_loss   | -0.0866  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66934    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 813      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 27680    |
# | train/             |          |
# |    actor_loss      | -69.4    |
# |    critic_loss     | 4.13     |
# |    ent_coef        | 0.0854   |
# |    ent_coef_loss   | -0.876   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66976    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 152      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 808      |
# |    time_elapsed    | 35       |
# |    total_timesteps | 28592    |
# | train/             |          |
# |    actor_loss      | -70.8    |
# |    critic_loss     | 1.96     |
# |    ent_coef        | 0.0844   |
# |    ent_coef_loss   | -0.516   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67033    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 806      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 29248    |
# | train/             |          |
# |    actor_loss      | -62.7    |
# |    critic_loss     | 1.79     |
# |    ent_coef        | 0.0833   |
# |    ent_coef_loss   | -0.166   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67074    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 191      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 802      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 30176    |
# | train/             |          |
# |    actor_loss      | -70.2    |
# |    critic_loss     | 1.76     |
# |    ent_coef        | 0.0821   |
# |    ent_coef_loss   | -1.02    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67132    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 212      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 800      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 30672    |
# | train/             |          |
# |    actor_loss      | -64.4    |
# |    critic_loss     | 1.98     |
# |    ent_coef        | 0.0814   |
# |    ent_coef_loss   | 0.00916  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67163    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 217      |
# |    ep_rew_mean     | 229      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 795      |
# |    time_elapsed    | 40       |
# |    total_timesteps | 31872    |
# | train/             |          |
# |    actor_loss      | -70.7    |
# |    critic_loss     | 4.88     |
# |    ent_coef        | 0.0805   |
# |    ent_coef_loss   | -0.607   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67238    |
# ---------------------------------
# Eval num_timesteps=32000, episode_reward=268.70 +/- 21.92
# Episode length: 215.40 +/- 49.20
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 215      |
# |    mean_reward     | 269      |
# | time/              |          |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -71.7    |
# |    critic_loss     | 10.2     |
# |    ent_coef        | 0.0804   |
# |    ent_coef_loss   | -1.06    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67246    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 221      |
# |    ep_rew_mean     | 252      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 767      |
# |    time_elapsed    | 42       |
# |    total_timesteps | 32272    |
# | train/             |          |
# |    actor_loss      | -65.6    |
# |    critic_loss     | 5.11     |
# |    ent_coef        | 0.0799   |
# |    ent_coef_loss   | -0.528   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67263    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 758      |
# |    time_elapsed    | 44       |
# |    total_timesteps | 33424    |
# | train/             |          |
# |    actor_loss      | -65.7    |
# |    critic_loss     | 2.26     |
# |    ent_coef        | 0.0784   |
# |    ent_coef_loss   | -0.173   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67335    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 754      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 33984    |
# | train/             |          |
# |    actor_loss      | -66.5    |
# |    critic_loss     | 3.75     |
# |    ent_coef        | 0.0779   |
# |    ent_coef_loss   | 0.0131   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67370    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 221      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 747      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 35008    |
# | train/             |          |
# |    actor_loss      | -71.7    |
# |    critic_loss     | 8.19     |
# |    ent_coef        | 0.0764   |
# |    ent_coef_loss   | -0.558   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67434    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 216      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 745      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 35744    |
# | train/             |          |
# |    actor_loss      | -62.9    |
# |    critic_loss     | 10.1     |
# |    ent_coef        | 0.0751   |
# |    ent_coef_loss   | -0.441   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67480    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 743      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 36464    |
# | train/             |          |
# |    actor_loss      | -68      |
# |    critic_loss     | 7.3      |
# |    ent_coef        | 0.0738   |
# |    ent_coef_loss   | -0.439   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67525    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 742      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 37056    |
# | train/             |          |
# |    actor_loss      | -74.7    |
# |    critic_loss     | 2.15     |
# |    ent_coef        | 0.0729   |
# |    ent_coef_loss   | -0.523   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67562    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 738      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 38560    |
# | train/             |          |
# |    actor_loss      | -74.1    |
# |    critic_loss     | 7.3      |
# |    ent_coef        | 0.0711   |
# |    ent_coef_loss   | -1.58    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67656    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 736      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 39200    |
# | train/             |          |
# |    actor_loss      | -69.4    |
# |    critic_loss     | 5.59     |
# |    ent_coef        | 0.0699   |
# |    ent_coef_loss   | -0.171   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67696    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 215      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 731      |
# |    time_elapsed    | 54       |
# |    total_timesteps | 40064    |
# | train/             |          |
# |    actor_loss      | -74.8    |
# |    critic_loss     | 1.8      |
# |    ent_coef        | 0.0684   |
# |    ent_coef_loss   | 0.0434   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67750    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 217      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 727      |
# |    time_elapsed    | 56       |
# |    total_timesteps | 40784    |
# | train/             |          |
# |    actor_loss      | -72.8    |
# |    critic_loss     | 4.29     |
# |    ent_coef        | 0.0677   |
# |    ent_coef_loss   | -0.463   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67795    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 216      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 726      |
# |    time_elapsed    | 56       |
# |    total_timesteps | 41232    |
# | train/             |          |
# |    actor_loss      | -71.9    |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.067    |
# |    ent_coef_loss   | -0.165   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67823    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 215      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 721      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 42704    |
# | train/             |          |
# |    actor_loss      | -73.6    |
# |    critic_loss     | 9.58     |
# |    ent_coef        | 0.0658   |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67915    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 719      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 43600    |
# | train/             |          |
# |    actor_loss      | -70.4    |
# |    critic_loss     | 9.74     |
# |    ent_coef        | 0.0652   |
# |    ent_coef_loss   | -0.046   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 67971    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 719      |
# |    time_elapsed    | 61       |
# |    total_timesteps | 44240    |
# | train/             |          |
# |    actor_loss      | -77.5    |
# |    critic_loss     | 6.46     |
# |    ent_coef        | 0.065    |
# |    ent_coef_loss   | -0.562   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68011    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | 274      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 715      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 45360    |
# | train/             |          |
# |    actor_loss      | -72.7    |
# |    critic_loss     | 3.51     |
# |    ent_coef        | 0.0638   |
# |    ent_coef_loss   | -0.522   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 713      |
# |    time_elapsed    | 64       |
# |    total_timesteps | 46336    |
# | train/             |          |
# |    actor_loss      | -71.9    |
# |    critic_loss     | 2.97     |
# |    ent_coef        | 0.0631   |
# |    ent_coef_loss   | -0.374   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68142    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | 274      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 710      |
# |    time_elapsed    | 65       |
# |    total_timesteps | 46912    |
# | train/             |          |
# |    actor_loss      | -72.4    |
# |    critic_loss     | 6.67     |
# |    ent_coef        | 0.0627   |
# |    ent_coef_loss   | -0.108   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68178    |
# ---------------------------------
# Eval num_timesteps=48000, episode_reward=279.25 +/- 23.85
# Episode length: 216.40 +/- 12.96
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 216      |
# |    mean_reward     | 279      |
# | time/              |          |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -76.4    |
# |    critic_loss     | 2.82     |
# |    ent_coef        | 0.0618   |
# |    ent_coef_loss   | -0.257   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68246    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 689      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 48400    |
# | train/             |          |
# |    actor_loss      | -73.9    |
# |    critic_loss     | 7.97     |
# |    ent_coef        | 0.0615   |
# |    ent_coef_loss   | -0.447   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68271    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 216      |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 688      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 48784    |
# | train/             |          |
# |    actor_loss      | -74.3    |
# |    critic_loss     | 11       |
# |    ent_coef        | 0.0614   |
# |    ent_coef_loss   | 0.936    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68295    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 687      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 49296    |
# | train/             |          |
# |    actor_loss      | -76.2    |
# |    critic_loss     | 2.77     |
# |    ent_coef        | 0.0616   |
# |    ent_coef_loss   | -0.989   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68327    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 687      |
# |    time_elapsed    | 73       |
# |    total_timesteps | 50592    |
# | train/             |          |
# |    actor_loss      | -76.8    |
# |    critic_loss     | 8.58     |
# |    ent_coef        | 0.0607   |
# |    ent_coef_loss   | -0.341   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68408    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 687      |
# |    time_elapsed    | 74       |
# |    total_timesteps | 51360    |
# | train/             |          |
# |    actor_loss      | -77.8    |
# |    critic_loss     | 6.78     |
# |    ent_coef        | 0.0599   |
# |    ent_coef_loss   | -0.332   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68456    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 687      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 52128    |
# | train/             |          |
# |    actor_loss      | -77.6    |
# |    critic_loss     | 21.3     |
# |    ent_coef        | 0.0595   |
# |    ent_coef_loss   | -1.32    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68504    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 685      |
# |    time_elapsed    | 77       |
# |    total_timesteps | 53088    |
# | train/             |          |
# |    actor_loss      | -77.5    |
# |    critic_loss     | 6.74     |
# |    ent_coef        | 0.0587   |
# |    ent_coef_loss   | -0.0852  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68564    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 685      |
# |    time_elapsed    | 77       |
# |    total_timesteps | 53408    |
# | train/             |          |
# |    actor_loss      | -70.8    |
# |    critic_loss     | 16.4     |
# |    ent_coef        | 0.0585   |
# |    ent_coef_loss   | 0.0508   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68584    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 683      |
# |    time_elapsed    | 79       |
# |    total_timesteps | 54352    |
# | train/             |          |
# |    actor_loss      | -80.1    |
# |    critic_loss     | 2.8      |
# |    ent_coef        | 0.0576   |
# |    ent_coef_loss   | 0.142    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68643    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 682      |
# |    time_elapsed    | 81       |
# |    total_timesteps | 55312    |
# | train/             |          |
# |    actor_loss      | -73.9    |
# |    critic_loss     | 9.16     |
# |    ent_coef        | 0.0566   |
# |    ent_coef_loss   | -0.353   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68703    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 680      |
# |    time_elapsed    | 82       |
# |    total_timesteps | 56416    |
# | train/             |          |
# |    actor_loss      | -76.5    |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.0561   |
# |    ent_coef_loss   | 0.137    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68772    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 679      |
# |    time_elapsed    | 84       |
# |    total_timesteps | 57088    |
# | train/             |          |
# |    actor_loss      | -73      |
# |    critic_loss     | 87.6     |
# |    ent_coef        | 0.0561   |
# |    ent_coef_loss   | 0.0023   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68814    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 679      |
# |    time_elapsed    | 84       |
# |    total_timesteps | 57520    |
# | train/             |          |
# |    actor_loss      | -80.4    |
# |    critic_loss     | 6.22     |
# |    ent_coef        | 0.056    |
# |    ent_coef_loss   | 0.179    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68841    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 680      |
# |    time_elapsed    | 86       |
# |    total_timesteps | 58896    |
# | train/             |          |
# |    actor_loss      | -76.8    |
# |    critic_loss     | 5.57     |
# |    ent_coef        | 0.0549   |
# |    ent_coef_loss   | 0.121    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68927    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 681      |
# |    time_elapsed    | 87       |
# |    total_timesteps | 59840    |
# | train/             |          |
# |    actor_loss      | -75.3    |
# |    critic_loss     | 1.67     |
# |    ent_coef        | 0.0547   |
# |    ent_coef_loss   | -0.462   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 68986    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 681      |
# |    time_elapsed    | 88       |
# |    total_timesteps | 60144    |
# | train/             |          |
# |    actor_loss      | -76.6    |
# |    critic_loss     | 6.78     |
# |    ent_coef        | 0.0545   |
# |    ent_coef_loss   | 0.316    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 69005    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 681      |
# |    time_elapsed    | 89       |
# |    total_timesteps | 61312    |
# | train/             |          |
# |    actor_loss      | -73.3    |
# |    critic_loss     | 4.36     |
# |    ent_coef        | 0.0546   |
# |    ent_coef_loss   | 0.611    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 69078    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 679      |
# |    time_elapsed    | 91       |
# |    total_timesteps | 62384    |
# | train/             |          |
# |    actor_loss      | -78.6    |
# |    critic_loss     | 6.2      |
# |    ent_coef        | 0.0538   |
# |    ent_coef_loss   | -0.075   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 69145    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 677      |
# |    time_elapsed    | 92       |
# |    total_timesteps | 62928    |
# | train/             |          |
# |    actor_loss      | -77.2    |
# |    critic_loss     | 9.94     |
# |    ent_coef        | 0.0534   |
# |    ent_coef_loss   | 0.212    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 69179    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 215      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 676      |
# |    time_elapsed    | 93       |
# |    total_timesteps | 63280    |
# | train/             |          |
# |    actor_loss      | -76.5    |
# |    critic_loss     | 11.7     |
# |    ent_coef        | 0.0531   |
# |    ent_coef_loss   | 0.0615   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 69201    |
# ---------------------------------
# Eval num_timesteps=64000, episode_reward=281.51 +/- 8.31
# Episode length: 205.80 +/- 7.86
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 206      |
# |    mean_reward     | 282      |
# | time/              |          |
# |    total_timesteps | 64000    |
# | train/             |          |
# |    actor_loss      | -75.1    |
# |    critic_loss     | 2.52     |
# |    ent_coef        | 0.0523   |
# |    ent_coef_loss   | -0.484   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 69246    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 215      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 665      |
# |    time_elapsed    | 97       |
# |    total_timesteps | 64720    |
# | train/             |          |
# |    actor_loss      | -75.4    |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.0524   |
# |    ent_coef_loss   | 1.33     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 69291    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 666      |
# |    time_elapsed    | 98       |
# |    total_timesteps | 65648    |
# | train/             |          |
# |    actor_loss      | -81.4    |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0525   |
# |    ent_coef_loss   | 0.375    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 69349    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 666      |
# |    time_elapsed    | 98       |
# |    total_timesteps | 65888    |
# | train/             |          |
# |    actor_loss      | -79.8    |
# |    critic_loss     | 4.6      |
# |    ent_coef        | 0.0524   |
# |    ent_coef_loss   | -0.0357  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 69364    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 667      |
# |    time_elapsed    | 100      |
# |    total_timesteps | 67440    |
# | train/             |          |
# |    actor_loss      | -79.8    |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.0533   |
# |    ent_coef_loss   | -0.528   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 69461    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 667      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 68096    |
# | train/             |          |
# |    actor_loss      | -81.1    |
# ...
# |    fps             | 611      |
# |    time_elapsed    | 1603     |
# |    total_timesteps | 980208   |
# | train/             |          |
# |    actor_loss      | -98.5    |
# |    critic_loss     | 2.86     |
# |    ent_coef        | 0.0306   |
# |    ent_coef_loss   | 0.632    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 126509   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 5012     |
# |    fps             | 611      |
# |    time_elapsed    | 1604     |
# |    total_timesteps | 980608   |
# | train/             |          |
# |    actor_loss      | -98.9    |
# |    critic_loss     | 7.14     |
# |    ent_coef        | 0.0306   |
# |    ent_coef_loss   | -0.186   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 126534   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 186      |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 5016     |
# |    fps             | 611      |
# |    time_elapsed    | 1605     |
# |    total_timesteps | 981440   |
# | train/             |          |
# |    actor_loss      | -97.1    |
# |    critic_loss     | 5.63     |
# |    ent_coef        | 0.0308   |
# |    ent_coef_loss   | 0.162    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 126586   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 183      |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 5020     |
# |    fps             | 611      |
# |    time_elapsed    | 1606     |
# |    total_timesteps | 982048   |
# | train/             |          |
# |    actor_loss      | -96.4    |
# |    critic_loss     | 7.23     |
# |    ent_coef        | 0.0308   |
# |    ent_coef_loss   | 0.939    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 126624   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 184      |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 5024     |
# |    fps             | 611      |
# |    time_elapsed    | 1608     |
# |    total_timesteps | 983216   |
# | train/             |          |
# |    actor_loss      | -98.4    |
# |    critic_loss     | 3.84     |
# |    ent_coef        | 0.031    |
# |    ent_coef_loss   | 0.086    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 126697   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 5028     |
# |    fps             | 611      |
# |    time_elapsed    | 1609     |
# |    total_timesteps | 984112   |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 6.31     |
# |    ent_coef        | 0.0312   |
# |    ent_coef_loss   | -0.51    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 126753   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 5032     |
# |    fps             | 611      |
# |    time_elapsed    | 1611     |
# |    total_timesteps | 985072   |
# | train/             |          |
# |    actor_loss      | -95.8    |
# |    critic_loss     | 11.1     |
# |    ent_coef        | 0.0314   |
# |    ent_coef_loss   | 0.0332   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 126813   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 187      |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 5036     |
# |    fps             | 611      |
# |    time_elapsed    | 1612     |
# |    total_timesteps | 985872   |
# | train/             |          |
# |    actor_loss      | -97.7    |
# |    critic_loss     | 3.31     |
# |    ent_coef        | 0.0309   |
# |    ent_coef_loss   | 0.158    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 126863   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 187      |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 5040     |
# |    fps             | 611      |
# |    time_elapsed    | 1613     |
# |    total_timesteps | 986608   |
# | train/             |          |
# |    actor_loss      | -97.6    |
# |    critic_loss     | 9.18     |
# |    ent_coef        | 0.03     |
# |    ent_coef_loss   | -0.0645  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 126909   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 189      |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 5044     |
# |    fps             | 611      |
# |    time_elapsed    | 1614     |
# |    total_timesteps | 987312   |
# | train/             |          |
# |    actor_loss      | -99.1    |
# |    critic_loss     | 2.95     |
# |    ent_coef        | 0.0296   |
# |    ent_coef_loss   | 0.0162   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 126953   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 5048     |
# |    fps             | 611      |
# |    time_elapsed    | 1615     |
# |    total_timesteps | 987888   |
# | train/             |          |
# |    actor_loss      | -96.9    |
# |    critic_loss     | 1.18     |
# |    ent_coef        | 0.0298   |
# |    ent_coef_loss   | 0.285    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 126989   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 193      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 5052     |
# |    fps             | 611      |
# |    time_elapsed    | 1616     |
# |    total_timesteps | 988704   |
# | train/             |          |
# |    actor_loss      | -98.1    |
# |    critic_loss     | 2.85     |
# |    ent_coef        | 0.0304   |
# |    ent_coef_loss   | 1.16     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127040   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 193      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 5056     |
# |    fps             | 611      |
# |    time_elapsed    | 1618     |
# |    total_timesteps | 989600   |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 2.5      |
# |    ent_coef        | 0.03     |
# |    ent_coef_loss   | -0.238   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127096   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 192      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 5060     |
# |    fps             | 611      |
# |    time_elapsed    | 1619     |
# |    total_timesteps | 990176   |
# | train/             |          |
# |    actor_loss      | -98.6    |
# |    critic_loss     | 5.88     |
# |    ent_coef        | 0.0299   |
# |    ent_coef_loss   | -0.149   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127132   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 192      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 5064     |
# |    fps             | 611      |
# |    time_elapsed    | 1619     |
# |    total_timesteps | 990720   |
# | train/             |          |
# |    actor_loss      | -98.3    |
# |    critic_loss     | 0.765    |
# |    ent_coef        | 0.0299   |
# |    ent_coef_loss   | 0.216    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127166   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    episodes        | 5068     |
# |    fps             | 611      |
# |    time_elapsed    | 1621     |
# |    total_timesteps | 991488   |
# | train/             |          |
# |    actor_loss      | -97.9    |
# |    critic_loss     | 2.5      |
# |    ent_coef        | 0.0298   |
# |    ent_coef_loss   | 0.605    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127214   |
# ---------------------------------
# Eval num_timesteps=992000, episode_reward=283.92 +/- 25.38
# Episode length: 198.80 +/- 23.46
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 199      |
# |    mean_reward     | 284      |
# | time/              |          |
# |    total_timesteps | 992000   |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 0.835    |
# |    ent_coef        | 0.0297   |
# |    ent_coef_loss   | -0.276   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127246   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    episodes        | 5072     |
# |    fps             | 611      |
# |    time_elapsed    | 1624     |
# |    total_timesteps | 992464   |
# | train/             |          |
# |    actor_loss      | -99.1    |
# |    critic_loss     | 1.26     |
# |    ent_coef        | 0.0297   |
# |    ent_coef_loss   | -1.38    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127275   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    episodes        | 5076     |
# |    fps             | 611      |
# |    time_elapsed    | 1625     |
# |    total_timesteps | 993440   |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 3.3      |
# |    ent_coef        | 0.0293   |
# |    ent_coef_loss   | -1.08    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127336   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 5080     |
# |    fps             | 611      |
# |    time_elapsed    | 1625     |
# |    total_timesteps | 993616   |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 5.64     |
# |    ent_coef        | 0.0293   |
# |    ent_coef_loss   | -0.67    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127347   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 5084     |
# |    fps             | 611      |
# |    time_elapsed    | 1627     |
# |    total_timesteps | 994672   |
# | train/             |          |
# |    actor_loss      | -98.9    |
# |    critic_loss     | 3.42     |
# |    ent_coef        | 0.0295   |
# |    ent_coef_loss   | -0.0505  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127413   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 192      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 5088     |
# |    fps             | 611      |
# |    time_elapsed    | 1628     |
# |    total_timesteps | 995504   |
# | train/             |          |
# |    actor_loss      | -97      |
# |    critic_loss     | 6.38     |
# |    ent_coef        | 0.0297   |
# |    ent_coef_loss   | -0.236   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127465   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 5092     |
# |    fps             | 611      |
# |    time_elapsed    | 1629     |
# |    total_timesteps | 996064   |
# | train/             |          |
# |    actor_loss      | -99.5    |
# |    critic_loss     | 13.2     |
# |    ent_coef        | 0.0294   |
# |    ent_coef_loss   | -0.717   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127500   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 5096     |
# |    fps             | 611      |
# |    time_elapsed    | 1629     |
# |    total_timesteps | 996416   |
# | train/             |          |
# |    actor_loss      | -98      |
# |    critic_loss     | 6.24     |
# |    ent_coef        | 0.0292   |
# |    ent_coef_loss   | -0.607   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127522   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    episodes        | 5100     |
# |    fps             | 611      |
# |    time_elapsed    | 1631     |
# |    total_timesteps | 997680   |
# | train/             |          |
# |    actor_loss      | -96.6    |
# |    critic_loss     | 0.741    |
# |    ent_coef        | 0.0295   |
# |    ent_coef_loss   | 0.31     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127601   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    episodes        | 5104     |
# |    fps             | 611      |
# |    time_elapsed    | 1632     |
# |    total_timesteps | 998176   |
# | train/             |          |
# |    actor_loss      | -95.9    |
# |    critic_loss     | 7.39     |
# |    ent_coef        | 0.0293   |
# |    ent_coef_loss   | -0.474   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127632   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 189      |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    episodes        | 5108     |
# |    fps             | 611      |
# |    time_elapsed    | 1633     |
# |    total_timesteps | 999200   |
# | train/             |          |
# |    actor_loss      | -95.8    |
# |    critic_loss     | 7.09     |
# |    ent_coef        | 0.0289   |
# |    ent_coef_loss   | 0.479    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127696   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 5112     |
# |    fps             | 611      |
# |    time_elapsed    | 1634     |
# |    total_timesteps | 999584   |
# | train/             |          |
# |    actor_loss      | -96.7    |
# |    critic_loss     | 2.96     |
# |    ent_coef        | 0.0288   |
# |    ent_coef_loss   | 0.657    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 127720   |
# ---------------------------------

# %%
model.save("data/policies/LunarLander-v2#sac#train_best")
del model
