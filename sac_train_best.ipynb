# %%
import gym

from stable_baselines3 import SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor

# %%
train_env = make_vec_env("LunarLanderContinuous-v2", n_envs=16)
eval_env = Monitor(gym.make("LunarLanderContinuous-v2"))
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./logs/continuous/sac",
    log_path="./logs/continuous/sac",
    eval_freq=1000,
    n_eval_episodes=10,
    deterministic=True,
    render=False,
)

# %%
model = SAC.load("logs/continuous/sac/best_model", env=train_env)

# %%
model.learn(total_timesteps=int(1e6), callback=eval_callback)
# Out:
# Logging to ./runs/sac_lunar_tensorboard/SAC_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.5     |
# |    ep_rew_mean     | -245     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 5720     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1616     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.8     |
# |    ep_rew_mean     | -209     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 5565     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1728     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 5416     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2304     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -210     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 5239     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2880     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -231     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 4876     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3488     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 4675     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3888     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | -220     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 4557     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 4304     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | -223     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 4489     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4528     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | -213     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 4431     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5248     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 115      |
# |    ep_rew_mean     | -219     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 4362     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5808     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | -218     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 4342     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5952     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -224     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 4320     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6496     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | -214     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 4268     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7184     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -215     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 4201     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7872     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 4147     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 8272     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -214     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 4106     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8512     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 114      |
# |    ep_rew_mean     | -215     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 4059     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8992     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 4012     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9488     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -219     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 3976     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9792     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -219     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 2760     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 10368    |
# | train/             |          |
# |    actor_loss      | -51      |
# |    critic_loss     | 60.4     |
# |    ent_coef        | 0.0287   |
# |    ent_coef_loss   | 11.9     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111268   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 1813     |
# |    time_elapsed    | 6        |
# |    total_timesteps | 12128    |
# | train/             |          |
# |    actor_loss      | -57.2    |
# |    critic_loss     | 8.94     |
# |    ent_coef        | 0.0381   |
# |    ent_coef_loss   | 6.96     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111378   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | -189     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 1602     |
# |    time_elapsed    | 8        |
# |    total_timesteps | 12864    |
# | train/             |          |
# |    actor_loss      | -55.6    |
# |    critic_loss     | 33.9     |
# |    ent_coef        | 0.0407   |
# |    ent_coef_loss   | 5.25     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111424   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | -172     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 1542     |
# |    time_elapsed    | 8        |
# |    total_timesteps | 13136    |
# | train/             |          |
# |    actor_loss      | -55.8    |
# |    critic_loss     | 50.4     |
# |    ent_coef        | 0.0415   |
# |    ent_coef_loss   | 4.93     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111441   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | -154     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 1461     |
# |    time_elapsed    | 9        |
# |    total_timesteps | 13648    |
# | train/             |          |
# |    actor_loss      | -51.7    |
# |    critic_loss     | 37.2     |
# |    ent_coef        | 0.0431   |
# |    ent_coef_loss   | 4.08     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111473   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 132      |
# |    ep_rew_mean     | -136     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 1268     |
# |    time_elapsed    | 11       |
# |    total_timesteps | 15184    |
# | train/             |          |
# |    actor_loss      | -56.4    |
# |    critic_loss     | 22.5     |
# |    ent_coef        | 0.0472   |
# |    ent_coef_loss   | 5.4      |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111569   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 137      |
# |    ep_rew_mean     | -115     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 1196     |
# |    time_elapsed    | 13       |
# |    total_timesteps | 15952    |
# | train/             |          |
# |    actor_loss      | -64.9    |
# |    critic_loss     | 9.68     |
# |    ent_coef        | 0.0497   |
# |    ent_coef_loss   | 5.24     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111617   |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=268.87 +/- 14.18
# Episode length: 249.30 +/- 116.61
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 249      |
# |    mean_reward     | 269      |
# | time/              |          |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -59.6    |
# |    critic_loss     | 9.58     |
# |    ent_coef        | 0.0498   |
# |    ent_coef_loss   | 4.54     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111620   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 140      |
# |    ep_rew_mean     | -97.6    |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 973      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 16496    |
# | train/             |          |
# |    actor_loss      | -70      |
# |    critic_loss     | 4.06     |
# |    ent_coef        | 0.0512   |
# |    ent_coef_loss   | 3.16     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111651   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 144      |
# |    ep_rew_mean     | -80.4    |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 909      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 18192    |
# | train/             |          |
# |    actor_loss      | -64      |
# |    critic_loss     | 26.2     |
# |    ent_coef        | 0.0554   |
# |    ent_coef_loss   | 4.35     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111757   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 147      |
# |    ep_rew_mean     | -62.6    |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 883      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 18992    |
# | train/             |          |
# |    actor_loss      | -60.9    |
# |    critic_loss     | 9.46     |
# |    ent_coef        | 0.0573   |
# |    ent_coef_loss   | 2.45     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111807   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 153      |
# |    ep_rew_mean     | -38.6    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 858      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 19840    |
# | train/             |          |
# |    actor_loss      | -69.1    |
# |    critic_loss     | 16.1     |
# |    ent_coef        | 0.0589   |
# |    ent_coef_loss   | 1.34     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111860   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 159      |
# |    ep_rew_mean     | -22.4    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 836      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 20896    |
# | train/             |          |
# |    actor_loss      | -74.5    |
# |    critic_loss     | 2.71     |
# |    ent_coef        | 0.0611   |
# |    ent_coef_loss   | 1.37     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111926   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | -1.78    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 814      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 21792    |
# | train/             |          |
# |    actor_loss      | -67.9    |
# |    critic_loss     | 23.5     |
# |    ent_coef        | 0.0625   |
# |    ent_coef_loss   | 1.35     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 111982   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 169      |
# |    ep_rew_mean     | 18.6     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 801      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 22560    |
# | train/             |          |
# |    actor_loss      | -69.5    |
# |    critic_loss     | 18.5     |
# |    ent_coef        | 0.0635   |
# |    ent_coef_loss   | 1.58     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112030   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 174      |
# |    ep_rew_mean     | 34.6     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 773      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 24128    |
# | train/             |          |
# |    actor_loss      | -67.5    |
# |    critic_loss     | 19.8     |
# |    ent_coef        | 0.0658   |
# |    ent_coef_loss   | 1.98     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112128   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 53.8     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 766      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 24576    |
# | train/             |          |
# |    actor_loss      | -67.3    |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0665   |
# |    ent_coef_loss   | 1.62     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112156   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | 73       |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 752      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 25952    |
# | train/             |          |
# |    actor_loss      | -77.5    |
# |    critic_loss     | 7.65     |
# |    ent_coef        | 0.0686   |
# |    ent_coef_loss   | 0.746    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112242   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 188      |
# |    ep_rew_mean     | 95.4     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 741      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 26912    |
# | train/             |          |
# |    actor_loss      | -71.8    |
# |    critic_loss     | 12.5     |
# |    ent_coef        | 0.0695   |
# |    ent_coef_loss   | 1.52     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112302   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 733      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 27616    |
# | train/             |          |
# |    actor_loss      | -69.5    |
# |    critic_loss     | 11.7     |
# |    ent_coef        | 0.0704   |
# |    ent_coef_loss   | 0.661    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112346   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 128      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 728      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 28096    |
# | train/             |          |
# |    actor_loss      | -75.1    |
# |    critic_loss     | 13.5     |
# |    ent_coef        | 0.0709   |
# |    ent_coef_loss   | 1.33     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112376   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 203      |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 719      |
# |    time_elapsed    | 40       |
# |    total_timesteps | 29120    |
# | train/             |          |
# |    actor_loss      | -72.1    |
# |    critic_loss     | 13.9     |
# |    ent_coef        | 0.0719   |
# |    ent_coef_loss   | 1.24     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 159      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 706      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 30848    |
# | train/             |          |
# |    actor_loss      | -69.8    |
# |    critic_loss     | 13.9     |
# |    ent_coef        | 0.0732   |
# |    ent_coef_loss   | 0.717    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112548   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 217      |
# |    ep_rew_mean     | 186      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 702      |
# |    time_elapsed    | 44       |
# |    total_timesteps | 31296    |
# | train/             |          |
# |    actor_loss      | -73.8    |
# |    critic_loss     | 21.4     |
# |    ent_coef        | 0.0735   |
# |    ent_coef_loss   | -0.161   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112576   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 699      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 31696    |
# | train/             |          |
# |    actor_loss      | -68.5    |
# |    critic_loss     | 71       |
# |    ent_coef        | 0.0736   |
# |    ent_coef_loss   | -0.454   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112601   |
# ---------------------------------
# Eval num_timesteps=32000, episode_reward=227.82 +/- 102.27
# Episode length: 212.30 +/- 62.70
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 212      |
# |    mean_reward     | 228      |
# | time/              |          |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -73.6    |
# |    critic_loss     | 7.77     |
# |    ent_coef        | 0.0736   |
# |    ent_coef_loss   | -0.542   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112620   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 225      |
# |    ep_rew_mean     | 219      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 664      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 32720    |
# | train/             |          |
# |    actor_loss      | -70.2    |
# |    critic_loss     | 7.46     |
# |    ent_coef        | 0.0737   |
# |    ent_coef_loss   | 0.902    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112665   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 235      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 656      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 34688    |
# | train/             |          |
# |    actor_loss      | -73.3    |
# |    critic_loss     | 19.6     |
# |    ent_coef        | 0.0736   |
# |    ent_coef_loss   | 0.0446   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112788   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 246      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 650      |
# |    time_elapsed    | 54       |
# |    total_timesteps | 35680    |
# | train/             |          |
# |    actor_loss      | -72.2    |
# |    critic_loss     | 35.8     |
# |    ent_coef        | 0.0734   |
# |    ent_coef_loss   | 0.54     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112850   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | 248      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 644      |
# |    time_elapsed    | 57       |
# |    total_timesteps | 36960    |
# | train/             |          |
# |    actor_loss      | -74.4    |
# |    critic_loss     | 25       |
# |    ent_coef        | 0.0738   |
# |    ent_coef_loss   | -0.267   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 112930   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 239      |
# |    ep_rew_mean     | 250      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 635      |
# |    time_elapsed    | 61       |
# |    total_timesteps | 38832    |
# | train/             |          |
# |    actor_loss      | -74      |
# |    critic_loss     | 26.8     |
# |    ent_coef        | 0.0742   |
# |    ent_coef_loss   | -0.804   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113047   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 630      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 39920    |
# | train/             |          |
# |    actor_loss      | -77      |
# |    critic_loss     | 26.2     |
# |    ent_coef        | 0.0743   |
# |    ent_coef_loss   | -0.634   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113115   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 243      |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 627      |
# |    time_elapsed    | 65       |
# |    total_timesteps | 40912    |
# | train/             |          |
# |    actor_loss      | -71.3    |
# |    critic_loss     | 6.3      |
# |    ent_coef        | 0.0743   |
# |    ent_coef_loss   | 0.0171   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113177   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 251      |
# |    ep_rew_mean     | 243      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 626      |
# |    time_elapsed    | 66       |
# |    total_timesteps | 41376    |
# | train/             |          |
# |    actor_loss      | -77.3    |
# |    critic_loss     | 2.07     |
# |    ent_coef        | 0.0743   |
# |    ent_coef_loss   | -0.648   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113206   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 259      |
# |    ep_rew_mean     | 240      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 624      |
# |    time_elapsed    | 68       |
# |    total_timesteps | 42528    |
# | train/             |          |
# |    actor_loss      | -72.9    |
# |    critic_loss     | 57       |
# |    ent_coef        | 0.0742   |
# |    ent_coef_loss   | -0.0532  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113278   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 259      |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 623      |
# |    time_elapsed    | 68       |
# |    total_timesteps | 42912    |
# | train/             |          |
# |    actor_loss      | -77.8    |
# |    critic_loss     | 4.27     |
# |    ent_coef        | 0.0741   |
# |    ent_coef_loss   | 0.195    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113302   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 258      |
# |    ep_rew_mean     | 245      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 621      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 43872    |
# | train/             |          |
# |    actor_loss      | -69.9    |
# |    critic_loss     | 38.3     |
# |    ent_coef        | 0.0739   |
# |    ent_coef_loss   | 0.271    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113362   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 255      |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 620      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 44496    |
# | train/             |          |
# |    actor_loss      | -70.7    |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.0737   |
# |    ent_coef_loss   | 0.101    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113401   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 252      |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 619      |
# |    time_elapsed    | 73       |
# |    total_timesteps | 45680    |
# | train/             |          |
# |    actor_loss      | -79.8    |
# |    critic_loss     | 5.43     |
# |    ent_coef        | 0.0741   |
# |    ent_coef_loss   | 0.436    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113475   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 250      |
# |    ep_rew_mean     | 245      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 618      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 46448    |
# | train/             |          |
# |    actor_loss      | -79.8    |
# |    critic_loss     | 8.2      |
# |    ent_coef        | 0.0747   |
# |    ent_coef_loss   | -0.142   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113523   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 248      |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 616      |
# |    time_elapsed    | 76       |
# |    total_timesteps | 47312    |
# | train/             |          |
# |    actor_loss      | -75.7    |
# |    critic_loss     | 10       |
# |    ent_coef        | 0.0747   |
# |    ent_coef_loss   | 0.0916   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113577   |
# ---------------------------------
# Eval num_timesteps=48000, episode_reward=262.39 +/- 20.89
# Episode length: 252.40 +/- 46.89
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 252      |
# |    mean_reward     | 262      |
# | time/              |          |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -80.5    |
# |    critic_loss     | 11.7     |
# |    ent_coef        | 0.0746   |
# |    ent_coef_loss   | -0.0966  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113620   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 251      |
# |    ep_rew_mean     | 245      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 595      |
# |    time_elapsed    | 80       |
# |    total_timesteps | 48160    |
# | train/             |          |
# |    actor_loss      | -73.5    |
# |    critic_loss     | 18       |
# |    ent_coef        | 0.0747   |
# |    ent_coef_loss   | 0.333    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113630   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 249      |
# |    ep_rew_mean     | 248      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 595      |
# |    time_elapsed    | 82       |
# |    total_timesteps | 48800    |
# | train/             |          |
# |    actor_loss      | -77.6    |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0745   |
# |    ent_coef_loss   | -0.448   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113670   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 247      |
# |    ep_rew_mean     | 246      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 594      |
# |    time_elapsed    | 83       |
# |    total_timesteps | 49920    |
# | train/             |          |
# |    actor_loss      | -79.7    |
# |    critic_loss     | 3.95     |
# |    ent_coef        | 0.0743   |
# |    ent_coef_loss   | 0.127    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113740   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 248      |
# |    ep_rew_mean     | 247      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 594      |
# |    time_elapsed    | 85       |
# |    total_timesteps | 50624    |
# | train/             |          |
# |    actor_loss      | -76.8    |
# |    critic_loss     | 3.96     |
# |    ent_coef        | 0.0743   |
# |    ent_coef_loss   | 0.684    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113784   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 249      |
# |    ep_rew_mean     | 246      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 594      |
# |    time_elapsed    | 86       |
# |    total_timesteps | 51392    |
# | train/             |          |
# |    actor_loss      | -69      |
# |    critic_loss     | 8.71     |
# |    ent_coef        | 0.0744   |
# |    ent_coef_loss   | 0.495    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113832   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 244      |
# |    ep_rew_mean     | 247      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 593      |
# |    time_elapsed    | 87       |
# |    total_timesteps | 51920    |
# | train/             |          |
# |    actor_loss      | -81.8    |
# |    critic_loss     | 7.54     |
# |    ent_coef        | 0.0742   |
# |    ent_coef_loss   | -0.237   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113865   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 244      |
# |    ep_rew_mean     | 249      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 593      |
# |    time_elapsed    | 89       |
# |    total_timesteps | 53200    |
# | train/             |          |
# |    actor_loss      | -76.1    |
# |    critic_loss     | 22.3     |
# |    ent_coef        | 0.0747   |
# |    ent_coef_loss   | 0.647    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 113945   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 246      |
# |    ep_rew_mean     | 254      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 592      |
# |    time_elapsed    | 91       |
# |    total_timesteps | 54080    |
# | train/             |          |
# |    actor_loss      | -79.3    |
# |    critic_loss     | 1.59     |
# |    ent_coef        | 0.0744   |
# |    ent_coef_loss   | -0.956   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 239      |
# |    ep_rew_mean     | 254      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 592      |
# |    time_elapsed    | 92       |
# |    total_timesteps | 54784    |
# | train/             |          |
# |    actor_loss      | -81.9    |
# |    critic_loss     | 7.96     |
# |    ent_coef        | 0.0741   |
# |    ent_coef_loss   | -0.446   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114044   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 237      |
# |    ep_rew_mean     | 254      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 592      |
# |    time_elapsed    | 92       |
# |    total_timesteps | 55056    |
# | train/             |          |
# |    actor_loss      | -79.6    |
# |    critic_loss     | 12.9     |
# |    ent_coef        | 0.0738   |
# |    ent_coef_loss   | -1.11    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114061   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 237      |
# |    ep_rew_mean     | 257      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 591      |
# |    time_elapsed    | 96       |
# |    total_timesteps | 57072    |
# | train/             |          |
# |    actor_loss      | -78.9    |
# |    critic_loss     | 16.3     |
# |    ent_coef        | 0.0723   |
# |    ent_coef_loss   | -0.444   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114187   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 236      |
# |    ep_rew_mean     | 260      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 590      |
# |    time_elapsed    | 97       |
# |    total_timesteps | 57584    |
# | train/             |          |
# |    actor_loss      | -79.4    |
# |    critic_loss     | 10.7     |
# |    ent_coef        | 0.0716   |
# |    ent_coef_loss   | 0.132    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114219   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | 259      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 589      |
# |    time_elapsed    | 98       |
# |    total_timesteps | 58256    |
# | train/             |          |
# |    actor_loss      | -80      |
# |    critic_loss     | 25.9     |
# |    ent_coef        | 0.0715   |
# |    ent_coef_loss   | -0.207   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114261   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 259      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 589      |
# |    time_elapsed    | 100      |
# |    total_timesteps | 59136    |
# | train/             |          |
# |    actor_loss      | -79.7    |
# |    critic_loss     | 4.04     |
# |    ent_coef        | 0.0707   |
# |    ent_coef_loss   | -0.147   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114316   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 225      |
# |    ep_rew_mean     | 259      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 588      |
# |    time_elapsed    | 102      |
# |    total_timesteps | 60624    |
# | train/             |          |
# |    actor_loss      | -76.6    |
# |    critic_loss     | 7.59     |
# |    ent_coef        | 0.0691   |
# |    ent_coef_loss   | -0.257   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114409   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 224      |
# |    ep_rew_mean     | 264      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 588      |
# |    time_elapsed    | 104      |
# |    total_timesteps | 61424    |
# | train/             |          |
# |    actor_loss      | -78.3    |
# |    critic_loss     | 3.99     |
# |    ent_coef        | 0.0683   |
# |    ent_coef_loss   | -0.358   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114459   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | 264      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 588      |
# |    time_elapsed    | 105      |
# |    total_timesteps | 61888    |
# | train/             |          |
# |    actor_loss      | -76.3    |
# |    critic_loss     | 18.3     |
# |    ent_coef        | 0.0677   |
# |    ent_coef_loss   | -0.358   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | 264      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 587      |
# |    time_elapsed    | 106      |
# |    total_timesteps | 62832    |
# | train/             |          |
# |    actor_loss      | -76.5    |
# |    critic_loss     | 6.83     |
# |    ent_coef        | 0.0673   |
# |    ent_coef_loss   | -0.0549  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114547   |
# ---------------------------------
# Eval num_timesteps=64000, episode_reward=246.18 +/- 81.69
# Episode length: 184.70 +/- 59.54
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 185      |
# |    mean_reward     | 246      |
# | time/              |          |
# |    total_timesteps | 64000    |
# | train/             |          |
# |    actor_loss      | -81      |
# |    critic_loss     | 4.02     |
# |    ent_coef        | 0.067    |
# |    ent_coef_loss   | -0.24    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114620   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 215      |
# |    ep_rew_mean     | 267      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 577      |
# |    time_elapsed    | 111      |
# |    total_timesteps | 64128    |
# | train/             |          |
# |    actor_loss      | -76.7    |
# |    critic_loss     | 19.6     |
# |    ent_coef        | 0.067    |
# |    ent_coef_loss   | -0.0324  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114628   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | 265      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 577      |
# |    time_elapsed    | 111      |
# |    total_timesteps | 64368    |
# | train/             |          |
# |    actor_loss      | -78.6    |
# |    critic_loss     | 2.98     |
# |    ent_coef        | 0.0669   |
# |    ent_coef_loss   | -0.347   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114643   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 265      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 577      |
# |    time_elapsed    | 112      |
# |    total_timesteps | 64768    |
# | train/             |          |
# |    actor_loss      | -77.1    |
# |    critic_loss     | 2.8      |
# |    ent_coef        | 0.0673   |
# |    ent_coef_loss   | 0.946    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114668   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 215      |
# |    ep_rew_mean     | 266      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 576      |
# |    time_elapsed    | 115      |
# |    total_timesteps | 66832    |
# | train/             |          |
# |    actor_loss      | -83.2    |
# |    critic_loss     | 19.3     |
# |    ent_coef        | 0.0681   |
# |    ent_coef_loss   | -0.288   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114797   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 215      |
# |    ep_rew_mean     | 266      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 575      |
# |    time_elapsed    | 117      |
# |    total_timesteps | 67744    |
# | train/             |          |
# |    actor_loss      | -79.4    |
# |    critic_loss     | 5.3      |
# |    ent_coef        | 0.0681   |
# |    ent_coef_loss   | 0.394    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114854   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 218      |
# |    ep_rew_mean     | 265      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 573      |
# |    time_elapsed    | 120      |
# |    total_timesteps | 69392    |
# | train/             |          |
# |    actor_loss      | -75.6    |
# |    critic_loss     | 3.09     |
# |    ent_coef        | 0.0685   |
# |    ent_coef_loss   | 0.369    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114957   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | 264      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 573      |
# |    time_elapsed    | 122      |
# |    total_timesteps | 70464    |
# | train/             |          |
# |    actor_loss      | -77.4    |
# |    critic_loss     | 4.97     |
# |    ent_coef        | 0.0683   |
# |    ent_coef_loss   | -0.456   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 115024   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | 262      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 572      |
# |    time_elapsed    | 124      |
# |    total_timesteps | 71280    |
# | train/             |          |
# |    actor_loss      | -75.8    |
# |    critic_loss     | 3.19     |
# |    ent_coef        | 0.0683   |
# |    ent_coef_loss   | 0.138    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 115075   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | 261      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 572      |
# |    time_elapsed    | 126      |
# |    total_timesteps | 72192    |
# | train/             |          |
# |    actor_loss      | -81.3    |
# |    critic_loss     | 2.24     |
# |    ent_coef        | 0.0682   |
# |    ent_coef_loss   | -0.263   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 115132   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 263      |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 572      |
# |    time_elapsed    | 127      |
# |    total_timesteps | 73168    |
# | train/             |          |
# |    actor_loss      | -82.1    |
# |    critic_loss     | 2.36     |
# |    ent_coef        | 0.0667   |
# |    ent_coef_loss   | -1.09    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 115193   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | 262      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 571      |
# |    time_elapsed    | 130      |
# |    total_timesteps | 74640    |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 26.2     |
# |    ent_coef        | 0.0635   |
# |    ent_coef_loss   | -0.644   |
# ...
# |    episodes        | 1360     |
# |    fps             | 535      |
# |    time_elapsed    | 531      |
# |    total_timesteps | 284400   |
# | train/             |          |
# |    actor_loss      | -82.2    |
# |    critic_loss     | 17.5     |
# |    ent_coef        | 0.0489   |
# |    ent_coef_loss   | -0.0804  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128395   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 216      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 1364     |
# |    fps             | 535      |
# |    time_elapsed    | 533      |
# |    total_timesteps | 285536   |
# | train/             |          |
# |    actor_loss      | -84.6    |
# |    critic_loss     | 7.42     |
# |    ent_coef        | 0.0478   |
# |    ent_coef_loss   | -0.134   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128466   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 1368     |
# |    fps             | 535      |
# |    time_elapsed    | 533      |
# |    total_timesteps | 285856   |
# | train/             |          |
# |    actor_loss      | -82.8    |
# |    critic_loss     | 8.4      |
# |    ent_coef        | 0.0474   |
# |    ent_coef_loss   | 0.52     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128486   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 1372     |
# |    fps             | 535      |
# |    time_elapsed    | 535      |
# |    total_timesteps | 286928   |
# | train/             |          |
# |    actor_loss      | -85.2    |
# |    critic_loss     | 1.43     |
# |    ent_coef        | 0.0479   |
# |    ent_coef_loss   | 0.0365   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128553   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 1376     |
# |    fps             | 535      |
# |    time_elapsed    | 536      |
# |    total_timesteps | 287600   |
# | train/             |          |
# |    actor_loss      | -82.4    |
# |    critic_loss     | 5.82     |
# |    ent_coef        | 0.0481   |
# |    ent_coef_loss   | -0.131   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128595   |
# ---------------------------------
# Eval num_timesteps=288000, episode_reward=262.73 +/- 21.12
# Episode length: 194.80 +/- 38.51
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 195      |
# |    mean_reward     | 263      |
# | time/              |          |
# |    total_timesteps | 288000   |
# | train/             |          |
# |    actor_loss      | -81.3    |
# |    critic_loss     | 4.48     |
# |    ent_coef        | 0.0477   |
# |    ent_coef_loss   | 0.383    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128620   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 1380     |
# |    fps             | 533      |
# |    time_elapsed    | 540      |
# |    total_timesteps | 288592   |
# | train/             |          |
# |    actor_loss      | -81      |
# |    critic_loss     | 11.8     |
# |    ent_coef        | 0.0467   |
# |    ent_coef_loss   | -0.0849  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128657   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 1384     |
# |    fps             | 533      |
# |    time_elapsed    | 541      |
# |    total_timesteps | 289024   |
# | train/             |          |
# |    actor_loss      | -84.3    |
# |    critic_loss     | 9.05     |
# |    ent_coef        | 0.0458   |
# |    ent_coef_loss   | -0.481   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128684   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 1388     |
# |    fps             | 534      |
# |    time_elapsed    | 543      |
# |    total_timesteps | 290272   |
# | train/             |          |
# |    actor_loss      | -86.3    |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0444   |
# |    ent_coef_loss   | -0.219   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128762   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 1392     |
# |    fps             | 534      |
# |    time_elapsed    | 544      |
# |    total_timesteps | 291104   |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 2        |
# |    ent_coef        | 0.0424   |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128814   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 1396     |
# |    fps             | 534      |
# |    time_elapsed    | 545      |
# |    total_timesteps | 291712   |
# | train/             |          |
# |    actor_loss      | -81.8    |
# |    critic_loss     | 5.48     |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | 1.01     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128852   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 534      |
# |    time_elapsed    | 546      |
# |    total_timesteps | 292080   |
# | train/             |          |
# |    actor_loss      | -84.9    |
# |    critic_loss     | 1.82     |
# |    ent_coef        | 0.0414   |
# |    ent_coef_loss   | 0.152    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128875   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 1404     |
# |    fps             | 534      |
# |    time_elapsed    | 548      |
# |    total_timesteps | 293104   |
# | train/             |          |
# |    actor_loss      | -84.2    |
# |    critic_loss     | 27.8     |
# |    ent_coef        | 0.0431   |
# |    ent_coef_loss   | 0.0276   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128939   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 1408     |
# |    fps             | 534      |
# |    time_elapsed    | 549      |
# |    total_timesteps | 293920   |
# | train/             |          |
# |    actor_loss      | -85.3    |
# |    critic_loss     | 6.65     |
# |    ent_coef        | 0.0436   |
# |    ent_coef_loss   | -0.305   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 128990   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 1412     |
# |    fps             | 534      |
# |    time_elapsed    | 551      |
# |    total_timesteps | 294656   |
# | train/             |          |
# |    actor_loss      | -85.2    |
# |    critic_loss     | 1.26     |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | -0.136   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129036   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 1416     |
# |    fps             | 534      |
# |    time_elapsed    | 552      |
# |    total_timesteps | 295424   |
# | train/             |          |
# |    actor_loss      | -80.3    |
# |    critic_loss     | 4.09     |
# |    ent_coef        | 0.0442   |
# |    ent_coef_loss   | 0.33     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129084   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 1420     |
# |    fps             | 534      |
# |    time_elapsed    | 554      |
# |    total_timesteps | 296640   |
# | train/             |          |
# |    actor_loss      | -83.8    |
# |    critic_loss     | 17.6     |
# |    ent_coef        | 0.0447   |
# |    ent_coef_loss   | 0.00604  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129160   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 1424     |
# |    fps             | 534      |
# |    time_elapsed    | 555      |
# |    total_timesteps | 297040   |
# | train/             |          |
# |    actor_loss      | -84.1    |
# |    critic_loss     | 2.39     |
# |    ent_coef        | 0.0444   |
# |    ent_coef_loss   | 0.452    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129185   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 1428     |
# |    fps             | 534      |
# |    time_elapsed    | 557      |
# |    total_timesteps | 298160   |
# | train/             |          |
# |    actor_loss      | -83.3    |
# |    critic_loss     | 1.4      |
# |    ent_coef        | 0.0445   |
# |    ent_coef_loss   | 0.514    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129255   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 1432     |
# |    fps             | 534      |
# |    time_elapsed    | 559      |
# |    total_timesteps | 299248   |
# | train/             |          |
# |    actor_loss      | -84.4    |
# |    critic_loss     | 1.59     |
# |    ent_coef        | 0.0441   |
# |    ent_coef_loss   | 0.105    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129323   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 1436     |
# |    fps             | 534      |
# |    time_elapsed    | 560      |
# |    total_timesteps | 299760   |
# | train/             |          |
# |    actor_loss      | -80.6    |
# |    critic_loss     | 1.32     |
# |    ent_coef        | 0.0435   |
# |    ent_coef_loss   | -0.269   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129355   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 1440     |
# |    fps             | 534      |
# |    time_elapsed    | 561      |
# |    total_timesteps | 300176   |
# | train/             |          |
# |    actor_loss      | -82.6    |
# |    critic_loss     | 7.55     |
# |    ent_coef        | 0.0433   |
# |    ent_coef_loss   | 0.0659   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129381   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 1444     |
# |    fps             | 534      |
# |    time_elapsed    | 563      |
# |    total_timesteps | 301552   |
# | train/             |          |
# |    actor_loss      | -84.5    |
# |    critic_loss     | 4.18     |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129467   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 1448     |
# |    fps             | 534      |
# |    time_elapsed    | 564      |
# |    total_timesteps | 302128   |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 53.7     |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | 1.26     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129503   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 1452     |
# |    fps             | 534      |
# |    time_elapsed    | 565      |
# |    total_timesteps | 302752   |
# | train/             |          |
# |    actor_loss      | -80.6    |
# |    critic_loss     | 11.1     |
# |    ent_coef        | 0.0427   |
# |    ent_coef_loss   | 0.346    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129542   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 203      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 1456     |
# |    fps             | 534      |
# |    time_elapsed    | 566      |
# |    total_timesteps | 303168   |
# | train/             |          |
# |    actor_loss      | -85.2    |
# |    critic_loss     | 9.6      |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | -0.569   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129568   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 203      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 1460     |
# |    fps             | 535      |
# |    time_elapsed    | 567      |
# |    total_timesteps | 303856   |
# | train/             |          |
# |    actor_loss      | -82.5    |
# |    critic_loss     | 4.34     |
# |    ent_coef        | 0.0418   |
# |    ent_coef_loss   | 0.49     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129611   |
# ---------------------------------
# Eval num_timesteps=304000, episode_reward=267.03 +/- 16.45
# Episode length: 182.00 +/- 11.96
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 182      |
# |    mean_reward     | 267      |
# | time/              |          |
# |    total_timesteps | 304000   |
# | train/             |          |
# |    actor_loss      | -85.7    |
# |    critic_loss     | 7.08     |
# |    ent_coef        | 0.0419   |
# |    ent_coef_loss   | 0.0639   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 129620   |
# ---------------------------------

# %%
model.save("data/policies/LunarLander-v2#sac#train_best")
del model
