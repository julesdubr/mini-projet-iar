# %%
import gym

from stable_baselines3 import SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor

# %%
train_env = make_vec_env("LunarLanderContinuous-v2", n_envs=16)
eval_env = Monitor(gym.make("LunarLanderContinuous-v2"))
eval_callback = EvalCallback(
    eval_env, 
    best_model_save_path="./logs/continuous/sac",
    log_path="./logs/continuous/sac",
    eval_freq=1000,
    n_eval_episodes=10,
    deterministic=True,
    render=False,
)

# %%
model = SAC.load("logs/continuous/sac/best_model", env=train_env)

# %%
model.learn(total_timesteps=int(1e6), callback=eval_callback)
# Out:
# Logging to ./runs/sac_lunar_tensorboard/SAC_5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 80       |
# |    ep_rew_mean     | -154     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 5356     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1344     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 86.6     |
# |    ep_rew_mean     | -167     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 5321     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1616     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.3     |
# |    ep_rew_mean     | -214     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 5275     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -209     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 5191     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2336     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -195     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 5261     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3056     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 5251     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3424     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 5153     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3936     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -197     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 5048     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 4368     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -206     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 5004     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 4704     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 4975     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 4848     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 4946     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5632     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -211     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 4888     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6192     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 4887     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6384     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 4920     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7072     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 4907     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7536     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 4915     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7792     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -207     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 4940     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 8240     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -204     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 4972     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 8736     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | -204     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 4986     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 9408     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 4981     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 9648     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 4997     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 9936     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | -207     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 3969     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 10448    |
# | train/             |          |
# |    actor_loss      | -58.7    |
# |    critic_loss     | 34.3     |
# |    ent_coef        | 0.0309   |
# |    ent_coef_loss   | 7.46     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 259395   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -196     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 2315     |
# |    time_elapsed    | 5        |
# |    total_timesteps | 12224    |
# | train/             |          |
# |    actor_loss      | -72.8    |
# |    critic_loss     | 61.2     |
# |    ent_coef        | 0.0403   |
# |    ent_coef_loss   | 6.18     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 259506   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 114      |
# |    ep_rew_mean     | -176     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 2131     |
# |    time_elapsed    | 5        |
# |    total_timesteps | 12640    |
# | train/             |          |
# |    actor_loss      | -75      |
# |    critic_loss     | 9.54     |
# |    ent_coef        | 0.042    |
# |    ent_coef_loss   | 3.9      |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 259532   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | -158     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 2067     |
# |    time_elapsed    | 6        |
# |    total_timesteps | 12816    |
# | train/             |          |
# |    actor_loss      | -64.2    |
# |    critic_loss     | 19.6     |
# |    ent_coef        | 0.0426   |
# |    ent_coef_loss   | 4.97     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 259543   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -140     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 1945     |
# |    time_elapsed    | 6        |
# |    total_timesteps | 13200    |
# | train/             |          |
# |    actor_loss      | -67.2    |
# |    critic_loss     | 74       |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | 3.34     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 259567   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 1526     |
# |    time_elapsed    | 9        |
# |    total_timesteps | 15168    |
# | train/             |          |
# |    actor_loss      | -76      |
# |    critic_loss     | 11.5     |
# |    ent_coef        | 0.0494   |
# |    ent_coef_loss   | 2.9      |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 259690   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | -98.4    |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 1469     |
# |    time_elapsed    | 10       |
# |    total_timesteps | 15600    |
# | train/             |          |
# |    actor_loss      | -77.8    |
# |    critic_loss     | 45.6     |
# |    ent_coef        | 0.0505   |
# |    ent_coef_loss   | 2.18     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 259717   |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=291.87 +/- 16.81
# Episode length: 196.90 +/- 67.27
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 197      |
# |    mean_reward     | 292      |
# | time/              |          |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -74.2    |
# |    critic_loss     | 9.53     |
# |    ent_coef        | 0.0514   |
# |    ent_coef_loss   | 2.19     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 259742   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | -79.6    |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 1199     |
# |    time_elapsed    | 13       |
# |    total_timesteps | 16720    |
# | train/             |          |
# |    actor_loss      | -69.1    |
# |    critic_loss     | 13.2     |
# |    ent_coef        | 0.0529   |
# |    ent_coef_loss   | 1.85     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 259787   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | -63.3    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 1156     |
# |    time_elapsed    | 14       |
# |    total_timesteps | 17296    |
# | train/             |          |
# |    actor_loss      | -78.4    |
# |    critic_loss     | 24.5     |
# |    ent_coef        | 0.0541   |
# |    ent_coef_loss   | 2.35     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 259823   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 140      |
# |    ep_rew_mean     | -44.8    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 1111     |
# |    time_elapsed    | 16       |
# |    total_timesteps | 18016    |
# | train/             |          |
# |    actor_loss      | -80.3    |
# |    critic_loss     | 12.4     |
# |    ent_coef        | 0.0556   |
# |    ent_coef_loss   | 1.88     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 259868   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 144      |
# |    ep_rew_mean     | -26.7    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 1015     |
# |    time_elapsed    | 19       |
# |    total_timesteps | 20016    |
# | train/             |          |
# |    actor_loss      | -84.8    |
# |    critic_loss     | 40.1     |
# |    ent_coef        | 0.059    |
# |    ent_coef_loss   | 0.834    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 259993   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 147      |
# |    ep_rew_mean     | -6.59    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 1009     |
# |    time_elapsed    | 19       |
# |    total_timesteps | 20160    |
# | train/             |          |
# |    actor_loss      | -76.6    |
# |    critic_loss     | 4.61     |
# |    ent_coef        | 0.0592   |
# |    ent_coef_loss   | 1.77     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260002   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 152      |
# |    ep_rew_mean     | 16       |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 999      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 20496    |
# | train/             |          |
# |    actor_loss      | -82.4    |
# |    critic_loss     | 20.3     |
# |    ent_coef        | 0.0598   |
# |    ent_coef_loss   | 2.26     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260023   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 156      |
# |    ep_rew_mean     | 39.6     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 963      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 22320    |
# | train/             |          |
# |    actor_loss      | -87.8    |
# |    critic_loss     | 16.4     |
# |    ent_coef        | 0.0632   |
# |    ent_coef_loss   | 1.1      |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260137   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 158      |
# |    ep_rew_mean     | 59.5     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 953      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 22816    |
# | train/             |          |
# |    actor_loss      | -80.6    |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.0641   |
# |    ent_coef_loss   | 1.12     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260168   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 161      |
# |    ep_rew_mean     | 77.4     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 946      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 23120    |
# | train/             |          |
# |    actor_loss      | -79.7    |
# |    critic_loss     | 9.09     |
# |    ent_coef        | 0.0646   |
# |    ent_coef_loss   | 1.86     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260187   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 165      |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 921      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 24304    |
# | train/             |          |
# |    actor_loss      | -83.6    |
# |    critic_loss     | 3.53     |
# |    ent_coef        | 0.0664   |
# |    ent_coef_loss   | 0.467    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260261   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 914      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 24848    |
# | train/             |          |
# |    actor_loss      | -85.2    |
# |    critic_loss     | 32.7     |
# |    ent_coef        | 0.0671   |
# |    ent_coef_loss   | 0.684    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260295   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 172      |
# |    ep_rew_mean     | 133      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 900      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 25920    |
# | train/             |          |
# |    actor_loss      | -89.4    |
# |    critic_loss     | 32.9     |
# |    ent_coef        | 0.0687   |
# |    ent_coef_loss   | 0.596    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260362   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 175      |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 886      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 27056    |
# | train/             |          |
# |    actor_loss      | -83.6    |
# |    critic_loss     | 9.45     |
# |    ent_coef        | 0.0701   |
# |    ent_coef_loss   | 1.02     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260433   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 179      |
# |    ep_rew_mean     | 172      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 879      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 27680    |
# | train/             |          |
# |    actor_loss      | -93.9    |
# |    critic_loss     | 5.48     |
# |    ent_coef        | 0.0706   |
# |    ent_coef_loss   | -0.15    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 182      |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 875      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 28128    |
# | train/             |          |
# |    actor_loss      | -88.8    |
# |    critic_loss     | 5.72     |
# |    ent_coef        | 0.0708   |
# |    ent_coef_loss   | 0.249    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260500   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | 208      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 871      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 28560    |
# | train/             |          |
# |    actor_loss      | -79.5    |
# |    critic_loss     | 6.64     |
# |    ent_coef        | 0.0711   |
# |    ent_coef_loss   | 0.417    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260527   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 193      |
# |    ep_rew_mean     | 231      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 866      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 29664    |
# | train/             |          |
# |    actor_loss      | -84.6    |
# |    critic_loss     | 12.9     |
# |    ent_coef        | 0.0717   |
# |    ent_coef_loss   | 0.659    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260596   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 195      |
# |    ep_rew_mean     | 250      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 861      |
# |    time_elapsed    | 35       |
# |    total_timesteps | 30496    |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 7.05     |
# |    ent_coef        | 0.0721   |
# |    ent_coef_loss   | 0.702    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260648   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 858      |
# |    time_elapsed    | 35       |
# |    total_timesteps | 30816    |
# | train/             |          |
# |    actor_loss      | -83.8    |
# |    critic_loss     | 9.81     |
# |    ent_coef        | 0.0721   |
# |    ent_coef_loss   | 0.576    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260668   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 856      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 31296    |
# | train/             |          |
# |    actor_loss      | -87.6    |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.0724   |
# |    ent_coef_loss   | 0.44     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260698   |
# ---------------------------------
# Eval num_timesteps=32000, episode_reward=283.97 +/- 12.99
# Episode length: 175.50 +/- 16.34
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 176      |
# |    mean_reward     | 284      |
# | time/              |          |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -88.5    |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.0725   |
# |    ent_coef_loss   | -0.287   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260742   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 829      |
# |    time_elapsed    | 39       |
# |    total_timesteps | 32656    |
# | train/             |          |
# |    actor_loss      | -85      |
# |    critic_loss     | 10.9     |
# |    ent_coef        | 0.0728   |
# |    ent_coef_loss   | -0.123   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260783   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 827      |
# |    time_elapsed    | 40       |
# |    total_timesteps | 33200    |
# | train/             |          |
# |    actor_loss      | -88.1    |
# |    critic_loss     | 9.27     |
# |    ent_coef        | 0.0728   |
# |    ent_coef_loss   | -0.0528  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260817   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 825      |
# |    time_elapsed    | 40       |
# |    total_timesteps | 33664    |
# | train/             |          |
# |    actor_loss      | -91.3    |
# |    critic_loss     | 7.81     |
# |    ent_coef        | 0.0726   |
# |    ent_coef_loss   | 0.274    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260846   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 824      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 33872    |
# | train/             |          |
# |    actor_loss      | -86.7    |
# |    critic_loss     | 90.1     |
# |    ent_coef        | 0.0726   |
# |    ent_coef_loss   | -0.162   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260859   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 819      |
# |    time_elapsed    | 42       |
# |    total_timesteps | 35088    |
# | train/             |          |
# |    actor_loss      | -86.4    |
# |    critic_loss     | 15.4     |
# |    ent_coef        | 0.0723   |
# |    ent_coef_loss   | -0.433   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260935   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 197      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 818      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 35664    |
# | train/             |          |
# |    actor_loss      | -91.5    |
# |    critic_loss     | 24.4     |
# |    ent_coef        | 0.0724   |
# |    ent_coef_loss   | 0.668    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 260971   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 193      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 817      |
# |    time_elapsed    | 44       |
# |    total_timesteps | 36304    |
# | train/             |          |
# |    actor_loss      | -90.6    |
# |    critic_loss     | 17.9     |
# |    ent_coef        | 0.0727   |
# |    ent_coef_loss   | -0.132   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261011   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 193      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 816      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 36848    |
# | train/             |          |
# |    actor_loss      | -88.2    |
# |    critic_loss     | 9.49     |
# |    ent_coef        | 0.0729   |
# |    ent_coef_loss   | -0.303   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261045   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 813      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 38128    |
# | train/             |          |
# |    actor_loss      | -87.6    |
# |    critic_loss     | 5.01     |
# |    ent_coef        | 0.0729   |
# |    ent_coef_loss   | 0.599    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261125   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 189      |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 810      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 39024    |
# | train/             |          |
# |    actor_loss      | -82.1    |
# |    critic_loss     | 9.57     |
# |    ent_coef        | 0.0731   |
# |    ent_coef_loss   | -0.296   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261181   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 188      |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 808      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 39504    |
# | train/             |          |
# |    actor_loss      | -84.6    |
# |    critic_loss     | 16       |
# |    ent_coef        | 0.0731   |
# |    ent_coef_loss   | 0.639    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261211   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 187      |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 801      |
# |    time_elapsed    | 50       |
# |    total_timesteps | 40864    |
# | train/             |          |
# |    actor_loss      | -94.1    |
# |    critic_loss     | 6.34     |
# |    ent_coef        | 0.0728   |
# |    ent_coef_loss   | -0.586   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261296   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 796      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 41792    |
# | train/             |          |
# |    actor_loss      | -87.4    |
# |    critic_loss     | 8.27     |
# |    ent_coef        | 0.073    |
# |    ent_coef_loss   | 0.709    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261354   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 193      |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 795      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 42288    |
# | train/             |          |
# |    actor_loss      | -88.1    |
# |    critic_loss     | 12.7     |
# |    ent_coef        | 0.0732   |
# |    ent_coef_loss   | -0.108   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261385   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 192      |
# |    ep_rew_mean     | 268      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 793      |
# |    time_elapsed    | 54       |
# |    total_timesteps | 42864    |
# | train/             |          |
# |    actor_loss      | -86.7    |
# |    critic_loss     | 6.82     |
# |    ent_coef        | 0.0731   |
# |    ent_coef_loss   | -0.333   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261421   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 189      |
# |    ep_rew_mean     | 268      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 789      |
# |    time_elapsed    | 56       |
# |    total_timesteps | 44208    |
# | train/             |          |
# |    actor_loss      | -88.5    |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.0725   |
# |    ent_coef_loss   | -0.104   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261505   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | 262      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 786      |
# |    time_elapsed    | 56       |
# |    total_timesteps | 44752    |
# | train/             |          |
# |    actor_loss      | -92      |
# |    critic_loss     | 7.76     |
# |    ent_coef        | 0.0722   |
# |    ent_coef_loss   | -0.293   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261539   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | 262      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 785      |
# |    time_elapsed    | 57       |
# |    total_timesteps | 45312    |
# | train/             |          |
# |    actor_loss      | -84      |
# |    critic_loss     | 7.1      |
# |    ent_coef        | 0.0722   |
# |    ent_coef_loss   | -0.0785  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261574   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 192      |
# |    ep_rew_mean     | 260      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 783      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 46672    |
# | train/             |          |
# |    actor_loss      | -88.9    |
# |    critic_loss     | 6.78     |
# |    ent_coef        | 0.0727   |
# |    ent_coef_loss   | 0.32     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261659   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | 260      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 781      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 47280    |
# | train/             |          |
# |    actor_loss      | -86.2    |
# |    critic_loss     | 6.53     |
# |    ent_coef        | 0.073    |
# |    ent_coef_loss   | -0.368   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261697   |
# ---------------------------------
# Eval num_timesteps=48000, episode_reward=253.61 +/- 65.00
# Episode length: 157.80 +/- 23.77
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 158      |
# |    mean_reward     | 254      |
# | time/              |          |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -89.6    |
# |    critic_loss     | 5.71     |
# |    ent_coef        | 0.0725   |
# |    ent_coef_loss   | -0.365   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261742   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | 260      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 769      |
# |    time_elapsed    | 62       |
# |    total_timesteps | 48032    |
# | train/             |          |
# |    actor_loss      | -88.1    |
# |    critic_loss     | 9.69     |
# |    ent_coef        | 0.0724   |
# |    ent_coef_loss   | 0.0234   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261744   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 186      |
# |    ep_rew_mean     | 260      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 768      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 48672    |
# | train/             |          |
# |    actor_loss      | -89.6    |
# |    critic_loss     | 3.34     |
# |    ent_coef        | 0.0719   |
# |    ent_coef_loss   | -0.383   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261784   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | 260      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 766      |
# |    time_elapsed    | 64       |
# |    total_timesteps | 49792    |
# | train/             |          |
# |    actor_loss      | -87.7    |
# |    critic_loss     | 6.08     |
# |    ent_coef        | 0.072    |
# |    ent_coef_loss   | 0.372    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261854   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | 261      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 763      |
# |    time_elapsed    | 66       |
# |    total_timesteps | 50528    |
# | train/             |          |
# |    actor_loss      | -86.5    |
# |    critic_loss     | 7.86     |
# |    ent_coef        | 0.0723   |
# |    ent_coef_loss   | -0.0024  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261900   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 183      |
# |    ep_rew_mean     | 259      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 762      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 51168    |
# | train/             |          |
# |    actor_loss      | -92.4    |
# |    critic_loss     | 5.48     |
# |    ent_coef        | 0.0721   |
# |    ent_coef_loss   | -0.109   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 261940   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | 259      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 758      |
# |    time_elapsed    | 69       |
# |    total_timesteps | 52496    |
# | train/             |          |
# |    actor_loss      | -84.3    |
# |    critic_loss     | 37.4     |
# |    ent_coef        | 0.0707   |
# |    ent_coef_loss   | -0.415   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262023   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | 258      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 756      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 53152    |
# | train/             |          |
# |    actor_loss      | -87.7    |
# |    critic_loss     | 3.72     |
# |    ent_coef        | 0.0701   |
# |    ent_coef_loss   | -0.263   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262064   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 259      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 755      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 53600    |
# | train/             |          |
# |    actor_loss      | -89.8    |
# |    critic_loss     | 49.8     |
# |    ent_coef        | 0.0698   |
# |    ent_coef_loss   | -0.392   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262092   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 259      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 753      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 54208    |
# | train/             |          |
# |    actor_loss      | -88.3    |
# |    critic_loss     | 7.64     |
# |    ent_coef        | 0.0694   |
# |    ent_coef_loss   | 0.208    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262130   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | 256      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 751      |
# |    time_elapsed    | 73       |
# |    total_timesteps | 55248    |
# | train/             |          |
# |    actor_loss      | -86.6    |
# |    critic_loss     | 8.53     |
# |    ent_coef        | 0.0687   |
# |    ent_coef_loss   | -0.681   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262195   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | 256      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 750      |
# |    time_elapsed    | 74       |
# |    total_timesteps | 55696    |
# | train/             |          |
# |    actor_loss      | -87.1    |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.0683   |
# |    ent_coef_loss   | 0.172    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262223   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 202      |
# |    ep_rew_mean     | 256      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 749      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 56640    |
# | train/             |          |
# |    actor_loss      | -86.9    |
# |    critic_loss     | 14.6     |
# |    ent_coef        | 0.0677   |
# |    ent_coef_loss   | 0.203    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262282   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 201      |
# |    ep_rew_mean     | 256      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 749      |
# |    time_elapsed    | 76       |
# |    total_timesteps | 57104    |
# | train/             |          |
# |    actor_loss      | -89.9    |
# |    critic_loss     | 8.72     |
# |    ent_coef        | 0.0677   |
# |    ent_coef_loss   | -0.296   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262311   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 255      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 749      |
# |    time_elapsed    | 77       |
# |    total_timesteps | 57712    |
# | train/             |          |
# |    actor_loss      | -84.4    |
# |    critic_loss     | 4.39     |
# |    ent_coef        | 0.0679   |
# |    ent_coef_loss   | 0.0711   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262349   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 201      |
# |    ep_rew_mean     | 256      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 749      |
# |    time_elapsed    | 77       |
# |    total_timesteps | 58368    |
# | train/             |          |
# |    actor_loss      | -90.7    |
# |    critic_loss     | 6.58     |
# |    ent_coef        | 0.0679   |
# |    ent_coef_loss   | -0.286   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262390   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | 255      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 749      |
# |    time_elapsed    | 79       |
# |    total_timesteps | 59280    |
# | train/             |          |
# |    actor_loss      | -90.7    |
# |    critic_loss     | 5.94     |
# |    ent_coef        | 0.0683   |
# |    ent_coef_loss   | 0.212    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262447   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | 256      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 749      |
# |    time_elapsed    | 79       |
# |    total_timesteps | 59856    |
# | train/             |          |
# |    actor_loss      | -86.8    |
# |    critic_loss     | 9.19     |
# |    ent_coef        | 0.0689   |
# |    ent_coef_loss   | 0.429    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262483   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | 263      |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 750      |
# |    time_elapsed    | 80       |
# |    total_timesteps | 60320    |
# | train/             |          |
# |    actor_loss      | -90.9    |
# |    critic_loss     | 8.96     |
# |    ent_coef        | 0.0693   |
# |    ent_coef_loss   | -0.29    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262512   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 267      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 750      |
# |    time_elapsed    | 81       |
# |    total_timesteps | 61184    |
# | train/             |          |
# |    actor_loss      | -89      |
# |    critic_loss     | 11.2     |
# |    ent_coef        | 0.0695   |
# |    ent_coef_loss   | -0.283   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262566   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 193      |
# |    ep_rew_mean     | 267      |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 750      |
# |    time_elapsed    | 82       |
# |    total_timesteps | 61872    |
# | train/             |          |
# |    actor_loss      | -89.1    |
# |    critic_loss     | 5.07     |
# |    ent_coef        | 0.0696   |
# |    ent_coef_loss   | 0.291    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 262609   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 750      |
# |    time_elapsed    | 83       |
# |    total_timesteps | 62912    |
# | train/             |          |
# ...
# |    fps             | 685      |
# |    time_elapsed    | 1433     |
# |    total_timesteps | 983088   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 5.18     |
# |    ent_coef        | 0.0265   |
# |    ent_coef_loss   | -0.089   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320185   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 5812     |
# |    fps             | 685      |
# |    time_elapsed    | 1434     |
# |    total_timesteps | 983776   |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 6.57     |
# |    ent_coef        | 0.0262   |
# |    ent_coef_loss   | 0.696    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320228   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 5816     |
# |    fps             | 685      |
# |    time_elapsed    | 1435     |
# |    total_timesteps | 984480   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 0.702    |
# |    ent_coef        | 0.026    |
# |    ent_coef_loss   | -0.184   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320272   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 5820     |
# |    fps             | 685      |
# |    time_elapsed    | 1435     |
# |    total_timesteps | 984896   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 1.52     |
# |    ent_coef        | 0.0257   |
# |    ent_coef_loss   | 0.244    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320298   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 5824     |
# |    fps             | 685      |
# |    time_elapsed    | 1436     |
# |    total_timesteps | 985552   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 2.79     |
# |    ent_coef        | 0.0256   |
# |    ent_coef_loss   | 0.207    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320339   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 5828     |
# |    fps             | 685      |
# |    time_elapsed    | 1438     |
# |    total_timesteps | 986464   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 2.08     |
# |    ent_coef        | 0.0254   |
# |    ent_coef_loss   | 0.0465   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320396   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 5832     |
# |    fps             | 685      |
# |    time_elapsed    | 1438     |
# |    total_timesteps | 986784   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 110      |
# |    ent_coef        | 0.0255   |
# |    ent_coef_loss   | -0.277   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320416   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    episodes        | 5836     |
# |    fps             | 686      |
# |    time_elapsed    | 1439     |
# |    total_timesteps | 987424   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 3.93     |
# |    ent_coef        | 0.0254   |
# |    ent_coef_loss   | -0.383   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320456   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 5840     |
# |    fps             | 686      |
# |    time_elapsed    | 1440     |
# |    total_timesteps | 988240   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 4.76     |
# |    ent_coef        | 0.0254   |
# |    ent_coef_loss   | 0.4      |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320507   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5844     |
# |    fps             | 686      |
# |    time_elapsed    | 1441     |
# |    total_timesteps | 988864   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 4.27     |
# |    ent_coef        | 0.0258   |
# |    ent_coef_loss   | 0.803    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320546   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5848     |
# |    fps             | 686      |
# |    time_elapsed    | 1442     |
# |    total_timesteps | 989616   |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 5.29     |
# |    ent_coef        | 0.0259   |
# |    ent_coef_loss   | -0.386   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320593   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5852     |
# |    fps             | 686      |
# |    time_elapsed    | 1443     |
# |    total_timesteps | 990128   |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 12.5     |
# |    ent_coef        | 0.0256   |
# |    ent_coef_loss   | 0.517    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320625   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5856     |
# |    fps             | 686      |
# |    time_elapsed    | 1444     |
# |    total_timesteps | 990736   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 3.41     |
# |    ent_coef        | 0.0257   |
# |    ent_coef_loss   | -0.173   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320663   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5860     |
# |    fps             | 686      |
# |    time_elapsed    | 1445     |
# |    total_timesteps | 991456   |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 4.84     |
# |    ent_coef        | 0.0254   |
# |    ent_coef_loss   | -0.0346  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320708   |
# ---------------------------------
# Eval num_timesteps=992000, episode_reward=273.99 +/- 12.99
# Episode length: 163.00 +/- 11.87
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 163      |
# |    mean_reward     | 274      |
# | time/              |          |
# |    total_timesteps | 992000   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 5.96     |
# |    ent_coef        | 0.0253   |
# |    ent_coef_loss   | 0.372    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320742   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5864     |
# |    fps             | 685      |
# |    time_elapsed    | 1446     |
# |    total_timesteps | 992128   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 0.749    |
# |    ent_coef        | 0.0255   |
# |    ent_coef_loss   | 0.16     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320750   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5868     |
# |    fps             | 685      |
# |    time_elapsed    | 1447     |
# |    total_timesteps | 992784   |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 3.66     |
# |    ent_coef        | 0.0258   |
# |    ent_coef_loss   | -0.329   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320791   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5872     |
# |    fps             | 685      |
# |    time_elapsed    | 1448     |
# |    total_timesteps | 993056   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 2.76     |
# |    ent_coef        | 0.0258   |
# |    ent_coef_loss   | -0.889   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5876     |
# |    fps             | 685      |
# |    time_elapsed    | 1449     |
# |    total_timesteps | 993952   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 2.59     |
# |    ent_coef        | 0.0261   |
# |    ent_coef_loss   | -0.418   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320864   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5880     |
# |    fps             | 685      |
# |    time_elapsed    | 1450     |
# |    total_timesteps | 994944   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 22.3     |
# |    ent_coef        | 0.0264   |
# |    ent_coef_loss   | 1.07     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320926   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    episodes        | 5884     |
# |    fps             | 685      |
# |    time_elapsed    | 1451     |
# |    total_timesteps | 995456   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 0.499    |
# |    ent_coef        | 0.0268   |
# |    ent_coef_loss   | -0.34    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320958   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5888     |
# |    fps             | 685      |
# |    time_elapsed    | 1452     |
# |    total_timesteps | 995824   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 3.04     |
# |    ent_coef        | 0.0271   |
# |    ent_coef_loss   | 0.797    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 320981   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5892     |
# |    fps             | 685      |
# |    time_elapsed    | 1453     |
# |    total_timesteps | 996720   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 6.64     |
# |    ent_coef        | 0.0281   |
# |    ent_coef_loss   | -0.445   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 321037   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 287      |
# | time/              |          |
# |    episodes        | 5896     |
# |    fps             | 685      |
# |    time_elapsed    | 1454     |
# |    total_timesteps | 997504   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 5.11     |
# |    ent_coef        | 0.0278   |
# |    ent_coef_loss   | 0.345    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 321086   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 289      |
# | time/              |          |
# |    episodes        | 5900     |
# |    fps             | 685      |
# |    time_elapsed    | 1455     |
# |    total_timesteps | 998080   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 5.57     |
# |    ent_coef        | 0.0278   |
# |    ent_coef_loss   | 0.293    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 321122   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 289      |
# | time/              |          |
# |    episodes        | 5904     |
# |    fps             | 685      |
# |    time_elapsed    | 1456     |
# |    total_timesteps | 998688   |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 0.873    |
# |    ent_coef        | 0.0277   |
# |    ent_coef_loss   | -0.91    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 321160   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 289      |
# | time/              |          |
# |    episodes        | 5908     |
# |    fps             | 685      |
# |    time_elapsed    | 1457     |
# |    total_timesteps | 999488   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 8.96     |
# |    ent_coef        | 0.0276   |
# |    ent_coef_loss   | -0.255   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 321210   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | 289      |
# | time/              |          |
# |    episodes        | 5912     |
# |    fps             | 685      |
# |    time_elapsed    | 1457     |
# |    total_timesteps | 999904   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 4.39     |
# |    ent_coef        | 0.0274   |
# |    ent_coef_loss   | -1.27    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 321236   |
# ---------------------------------

# %%
model.save("data/policies/LunarLanderContinuous-v2#sac#train_best")
del model
