# %%
import gym

from sb3_contrib import TQC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor

# %%
train_env = make_vec_env("LunarLanderContinuous-v2", n_envs=16)
eval_env = Monitor(gym.make("LunarLanderContinuous-v2"))

# %%
from typing import Callable

def linear_schedule(initial_value):
    """
    Linear learning rate schedule.
    :param initial_value: (float or str)
    :return: (function)
    """
    def func(progress):
        """
        Progress will decrease from 1 (beginning) to 0
        :param progress: (float)
        :return: (float)
        """
        return progress * initial_value

    return func

# %%
model = TQC(
    "MlpPolicy",
    train_env,
    learning_rate=linear_schedule(7.3e-4),
    buffer_size=1000000,
    batch_size=256,
    ent_coef='auto',
    gamma=0.99,
    tau=0.01,
    train_freq=1,
    gradient_steps=1,
    learning_starts=10000,
    policy_kwargs=dict(net_arch=[400, 300]),
    verbose=1,
    tensorboard_log="./runs/tqc_lunarcontinuous_tensorboard/"
)
# Out:
# Using cuda device

# %%
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./logs/continuous/tqc",
    log_path="./logs/continuous/tqc",
    eval_freq=1000,
    n_eval_episodes=10,
    deterministic=True,
    render=False,
)

# %%
model.learn(total_timesteps=int(5e5), callback=eval_callback)
# Out:
# Logging to ./runs/tqc_lunar_tensorboard/TQC_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.8     |
# |    ep_rew_mean     | -77.1    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 3668     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1264     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.1     |
# |    ep_rew_mean     | -160     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 3780     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1552     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.9     |
# |    ep_rew_mean     | -221     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 3851     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1712     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.7     |
# |    ep_rew_mean     | -214     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 3930     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2608     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.2     |
# |    ep_rew_mean     | -194     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 3867     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3088     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.4     |
# |    ep_rew_mean     | -199     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 3804     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3344     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | -210     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 3752     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3696     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -206     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 3607     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4272     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 3573     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4864     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -207     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 3592     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5296     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 3572     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5616     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -220     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 3548     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6128     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -225     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 3522     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6368     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -221     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 3450     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6864     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 3399     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 7424     |
# ---------------------------------
# C:\Users\Jules Dubreuil\AppData\Roaming\Python\Python310\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=8000, episode_reward=-158.61 +/- 13.86
# Episode length: 61.40 +/- 7.53
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 61.4     |
# |    mean_reward     | -159     |
# | time/              |          |
# |    total_timesteps | 8000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 2420     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8160     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -210     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 2438     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8384     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 2447     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8496     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -210     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 2493     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8880     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -211     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 2599     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 9776     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -213     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 2615     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 9968     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -212     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 2360     |
# |    time_elapsed    | 4        |
# |    total_timesteps | 10288    |
# | train/             |          |
# |    actor_loss      | -1.5     |
# |    critic_loss     | 0.648    |
# |    ent_coef        | 0.989    |
# |    ent_coef_loss   | -0.0385  |
# |    learning_rate   | 0.000715 |
# |    n_updates       | 17       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -213     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 2201     |
# |    time_elapsed    | 4        |
# |    total_timesteps | 10592    |
# | train/             |          |
# |    actor_loss      | -1.4     |
# |    critic_loss     | 1.53     |
# |    ent_coef        | 0.975    |
# |    ent_coef_loss   | -0.084   |
# |    learning_rate   | 0.000715 |
# |    n_updates       | 36       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -211     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 1920     |
# |    time_elapsed    | 5        |
# |    total_timesteps | 11280    |
# | train/             |          |
# |    actor_loss      | -1.47    |
# |    critic_loss     | 0.517    |
# |    ent_coef        | 0.946    |
# |    ent_coef_loss   | -0.181   |
# |    learning_rate   | 0.000714 |
# |    n_updates       | 79       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -206     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 1769     |
# |    time_elapsed    | 6        |
# |    total_timesteps | 11696    |
# | train/             |          |
# |    actor_loss      | -1.45    |
# |    critic_loss     | 0.551    |
# |    ent_coef        | 0.929    |
# |    ent_coef_loss   | -0.237   |
# |    learning_rate   | 0.000713 |
# |    n_updates       | 105      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | -209     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 1639     |
# |    time_elapsed    | 7        |
# |    total_timesteps | 12384    |
# | train/             |          |
# |    actor_loss      | -1.4     |
# |    critic_loss     | 0.749    |
# |    ent_coef        | 0.902    |
# |    ent_coef_loss   | -0.315   |
# |    learning_rate   | 0.000712 |
# |    n_updates       | 148      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -206     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 1526     |
# |    time_elapsed    | 8        |
# |    total_timesteps | 13152    |
# | train/             |          |
# |    actor_loss      | -1.76    |
# |    critic_loss     | 0.865    |
# |    ent_coef        | 0.874    |
# |    ent_coef_loss   | -0.375   |
# |    learning_rate   | 0.000711 |
# |    n_updates       | 196      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 114      |
# |    ep_rew_mean     | -198     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 1424     |
# |    time_elapsed    | 9        |
# |    total_timesteps | 14016    |
# | train/             |          |
# |    actor_loss      | -1.84    |
# |    critic_loss     | 1.1      |
# |    ent_coef        | 0.843    |
# |    ent_coef_loss   | -0.504   |
# |    learning_rate   | 0.00071  |
# |    n_updates       | 250      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | -199     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 1352     |
# |    time_elapsed    | 10       |
# |    total_timesteps | 14784    |
# | train/             |          |
# |    actor_loss      | -1.77    |
# |    critic_loss     | 0.478    |
# |    ent_coef        | 0.817    |
# |    ent_coef_loss   | -0.563   |
# |    learning_rate   | 0.000708 |
# |    n_updates       | 298      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | -201     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 1336     |
# |    time_elapsed    | 11       |
# |    total_timesteps | 14960    |
# | train/             |          |
# |    actor_loss      | -2.15    |
# |    critic_loss     | 0.861    |
# |    ent_coef        | 0.811    |
# |    ent_coef_loss   | -0.572   |
# |    learning_rate   | 0.000708 |
# |    n_updates       | 309      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -197     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 1275     |
# |    time_elapsed    | 12       |
# |    total_timesteps | 15904    |
# | train/             |          |
# |    actor_loss      | -1.99    |
# |    critic_loss     | 0.762    |
# |    ent_coef        | 0.78     |
# |    ent_coef_loss   | -0.72    |
# |    learning_rate   | 0.000707 |
# |    n_updates       | 368      |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=-269.44 +/- 84.83
# Episode length: 265.00 +/- 95.86
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 265      |
# |    mean_reward     | -269     |
# | time/              |          |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -1.36    |
# |    critic_loss     | 0.652    |
# |    ent_coef        | 0.777    |
# |    ent_coef_loss   | -0.724   |
# |    learning_rate   | 0.000707 |
# |    n_updates       | 374      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 1052     |
# |    time_elapsed    | 15       |
# |    total_timesteps | 16704    |
# | train/             |          |
# |    actor_loss      | -1.91    |
# |    critic_loss     | 1.18     |
# |    ent_coef        | 0.755    |
# |    ent_coef_loss   | -0.803   |
# |    learning_rate   | 0.000706 |
# |    n_updates       | 418      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | -189     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 1021     |
# |    time_elapsed    | 17       |
# |    total_timesteps | 17760    |
# | train/             |          |
# |    actor_loss      | -0.516   |
# |    critic_loss     | 0.985    |
# |    ent_coef        | 0.723    |
# |    ent_coef_loss   | -0.919   |
# |    learning_rate   | 0.000704 |
# |    n_updates       | 484      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | -189     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 992      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 18912    |
# | train/             |          |
# |    actor_loss      | -1.31    |
# |    critic_loss     | 0.908    |
# |    ent_coef        | 0.69     |
# |    ent_coef_loss   | -0.987   |
# |    learning_rate   | 0.000702 |
# |    n_updates       | 556      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | -184     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 966      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 19792    |
# | train/             |          |
# |    actor_loss      | -1.19    |
# |    critic_loss     | 0.868    |
# |    ent_coef        | 0.666    |
# |    ent_coef_loss   | -1.12    |
# |    learning_rate   | 0.000701 |
# |    n_updates       | 611      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | -174     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 909      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 22016    |
# | train/             |          |
# |    actor_loss      | -1.35    |
# |    critic_loss     | 0.791    |
# |    ent_coef        | 0.61     |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 0.000698 |
# |    n_updates       | 750      |
# ---------------------------------
# Eval num_timesteps=24000, episode_reward=-186.14 +/- 19.86
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -186     |
# | time/              |          |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -2.17    |
# |    critic_loss     | 0.904    |
# |    ent_coef        | 0.565    |
# |    ent_coef_loss   | -1.39    |
# |    learning_rate   | 0.000695 |
# |    n_updates       | 874      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 153      |
# |    ep_rew_mean     | -166     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 525      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 25184    |
# | train/             |          |
# |    actor_loss      | -2.46    |
# |    critic_loss     | 1.1      |
# |    ent_coef        | 0.54     |
# |    ent_coef_loss   | -1.4     |
# |    learning_rate   | 0.000693 |
# |    n_updates       | 948      |
# ---------------------------------
# Eval num_timesteps=32000, episode_reward=-108.54 +/- 11.34
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -109     |
# | time/              |          |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | 1.02     |
# |    critic_loss     | 1.27     |
# |    ent_coef        | 0.42     |
# |    ent_coef_loss   | -1.82    |
# |    learning_rate   | 0.000683 |
# |    n_updates       | 1374     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 178      |
# |    ep_rew_mean     | -157     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 372      |
# |    time_elapsed    | 90       |
# |    total_timesteps | 33760    |
# | train/             |          |
# |    actor_loss      | -0.798   |
# |    critic_loss     | 1.06     |
# |    ent_coef        | 0.394    |
# |    ent_coef_loss   | -1.86    |
# |    learning_rate   | 0.000681 |
# |    n_updates       | 1484     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 215      |
# |    ep_rew_mean     | -151     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 369      |
# |    time_elapsed    | 96       |
# |    total_timesteps | 35792    |
# | train/             |          |
# |    actor_loss      | -0.597   |
# |    critic_loss     | 1.23     |
# |    ent_coef        | 0.367    |
# |    ent_coef_loss   | -1.96    |
# |    learning_rate   | 0.000678 |
# |    n_updates       | 1611     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 250      |
# |    ep_rew_mean     | -146     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 365      |
# |    time_elapsed    | 103      |
# |    total_timesteps | 38016    |
# | train/             |          |
# |    actor_loss      | -1.82    |
# |    critic_loss     | 1.05     |
# |    ent_coef        | 0.34     |
# |    ent_coef_loss   | -2.18    |
# |    learning_rate   | 0.000675 |
# |    n_updates       | 1750     |
# ---------------------------------
# Eval num_timesteps=40000, episode_reward=-185.00 +/- 42.05
# Episode length: 667.60 +/- 181.34
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 668      |
# |    mean_reward     | -185     |
# | time/              |          |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -0.727   |
# |    critic_loss     | 1.4      |
# |    ent_coef        | 0.318    |
# |    ent_coef_loss   | -2.05    |
# |    learning_rate   | 0.000672 |
# |    n_updates       | 1874     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 285      |
# |    ep_rew_mean     | -139     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 340      |
# |    time_elapsed    | 121      |
# |    total_timesteps | 41184    |
# | train/             |          |
# |    actor_loss      | -1.05    |
# |    critic_loss     | 1.18     |
# |    ent_coef        | 0.305    |
# |    ent_coef_loss   | -2.29    |
# |    learning_rate   | 0.00067  |
# |    n_updates       | 1948     |
# ---------------------------------
# Eval num_timesteps=48000, episode_reward=-99.74 +/- 28.86
# Episode length: 931.20 +/- 137.60
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 931      |
# |    mean_reward     | -99.7    |
# | time/              |          |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -3.73    |
# |    critic_loss     | 0.861    |
# |    ent_coef        | 0.241    |
# |    ent_coef_loss   | -2.88    |
# |    learning_rate   | 0.00066  |
# |    n_updates       | 2374     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 321      |
# |    ep_rew_mean     | -135     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 313      |
# |    time_elapsed    | 158      |
# |    total_timesteps | 49760    |
# | train/             |          |
# |    actor_loss      | -0.806   |
# |    critic_loss     | 1.25     |
# |    ent_coef        | 0.227    |
# |    ent_coef_loss   | -2.89    |
# |    learning_rate   | 0.000657 |
# |    n_updates       | 2484     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 356      |
# |    ep_rew_mean     | -127     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 313      |
# |    time_elapsed    | 165      |
# |    total_timesteps | 51792    |
# | train/             |          |
# |    actor_loss      | -1.58    |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.211    |
# |    ent_coef_loss   | -2.74    |
# |    learning_rate   | 0.000654 |
# |    n_updates       | 2611     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 392      |
# |    ep_rew_mean     | -124     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 316      |
# |    time_elapsed    | 170      |
# |    total_timesteps | 54016    |
# | train/             |          |
# |    actor_loss      | -4.62    |
# |    critic_loss     | 0.93     |
# |    ent_coef        | 0.195    |
# |    ent_coef_loss   | -2.57    |
# |    learning_rate   | 0.000651 |
# |    n_updates       | 2750     |
# ---------------------------------
# Eval num_timesteps=56000, episode_reward=-146.79 +/- 44.46
# Episode length: 895.60 +/- 132.03
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 896      |
# |    mean_reward     | -147     |
# | time/              |          |
# |    total_timesteps | 56000    |
# | train/             |          |
# |    actor_loss      | -6.9     |
# |    critic_loss     | 0.741    |
# |    ent_coef        | 0.182    |
# |    ent_coef_loss   | -3       |
# |    learning_rate   | 0.000648 |
# |    n_updates       | 2874     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 428      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 302      |
# |    time_elapsed    | 189      |
# |    total_timesteps | 57184    |
# | train/             |          |
# |    actor_loss      | -6.19    |
# |    critic_loss     | 0.933    |
# |    ent_coef        | 0.175    |
# |    ent_coef_loss   | -3.34    |
# |    learning_rate   | 0.000647 |
# |    n_updates       | 2948     |
# ---------------------------------
# Eval num_timesteps=64000, episode_reward=-102.90 +/- 28.20
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -103     |
# | time/              |          |
# |    total_timesteps | 64000    |
# | train/             |          |
# |    actor_loss      | -4.6     |
# |    critic_loss     | 0.964    |
# |    ent_coef        | 0.138    |
# |    ent_coef_loss   | -2.82    |
# |    learning_rate   | 0.000637 |
# |    n_updates       | 3374     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 464      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 291      |
# |    time_elapsed    | 225      |
# |    total_timesteps | 65760    |
# | train/             |          |
# |    actor_loss      | -6.65    |
# |    critic_loss     | 0.666    |
# |    ent_coef        | 0.129    |
# |    ent_coef_loss   | -2.79    |
# |    learning_rate   | 0.000634 |
# |    n_updates       | 3484     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 291      |
# |    time_elapsed    | 232      |
# |    total_timesteps | 67792    |
# | train/             |          |
# |    actor_loss      | -4.5     |
# |    critic_loss     | 0.856    |
# |    ent_coef        | 0.12     |
# |    ent_coef_loss   | -3.29    |
# |    learning_rate   | 0.000631 |
# |    n_updates       | 3611     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 535      |
# |    ep_rew_mean     | -98.3    |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 293      |
# |    time_elapsed    | 238      |
# |    total_timesteps | 70016    |
# | train/             |          |
# |    actor_loss      | -8.01    |
# |    critic_loss     | 0.533    |
# |    ent_coef        | 0.111    |
# |    ent_coef_loss   | -4.09    |
# |    learning_rate   | 0.000628 |
# |    n_updates       | 3750     |
# ---------------------------------
# Eval num_timesteps=72000, episode_reward=-30.66 +/- 18.31
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -30.7    |
# | time/              |          |
# |    total_timesteps | 72000    |
# | train/             |          |
# |    actor_loss      | -5.54    |
# |    critic_loss     | 1.22     |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | -3.72    |
# |    learning_rate   | 0.000625 |
# |    n_updates       | 3874     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 571      |
# |    ep_rew_mean     | -92.9    |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 280      |
# |    time_elapsed    | 261      |
# |    total_timesteps | 73184    |
# | train/             |          |
# |    actor_loss      | -6.35    |
# |    critic_loss     | 0.718    |
# |    ent_coef        | 0.1      |
# |    ent_coef_loss   | -3.64    |
# |    learning_rate   | 0.000623 |
# |    n_updates       | 3948     |
# ---------------------------------
# Eval num_timesteps=80000, episode_reward=-16.98 +/- 4.80
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -17      |
# | time/              |          |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -5.89    |
# |    critic_loss     | 0.721    |
# |    ent_coef        | 0.0799   |
# |    ent_coef_loss   | -3.25    |
# |    learning_rate   | 0.000613 |
# |    n_updates       | 4374     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 607      |
# |    ep_rew_mean     | -91.1    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 275      |
# |    time_elapsed    | 297      |
# |    total_timesteps | 81760    |
# | train/             |          |
# |    actor_loss      | -0.371   |
# |    critic_loss     | 0.97     |
# |    ent_coef        | 0.0757   |
# |    ent_coef_loss   | -2.85    |
# |    learning_rate   | 0.000611 |
# |    n_updates       | 4484     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 642      |
# |    ep_rew_mean     | -87      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 275      |
# |    time_elapsed    | 304      |
# |    total_timesteps | 83792    |
# | train/             |          |
# |    actor_loss      | -6.75    |
# |    critic_loss     | 0.7      |
# |    ent_coef        | 0.0714   |
# |    ent_coef_loss   | -2.38    |
# |    learning_rate   | 0.000608 |
# |    n_updates       | 4611     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 676      |
# |    ep_rew_mean     | -81.6    |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 276      |
# |    time_elapsed    | 310      |
# |    total_timesteps | 86016    |
# | train/             |          |
# |    actor_loss      | -5.59    |
# |    critic_loss     | 0.999    |
# |    ent_coef        | 0.0673   |
# |    ent_coef_loss   | -3.67    |
# |    learning_rate   | 0.000604 |
# |    n_updates       | 4750     |
# ---------------------------------
# Eval num_timesteps=88000, episode_reward=-12.44 +/- 16.72
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -12.4    |
# | time/              |          |
# |    total_timesteps | 88000    |
# | train/             |          |
# |    actor_loss      | 0.46     |
# |    critic_loss     | 1.23     |
# |    ent_coef        | 0.0643   |
# |    ent_coef_loss   | -2.71    |
# |    learning_rate   | 0.000602 |
# |    n_updates       | 4874     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 709      |
# |    ep_rew_mean     | -75.9    |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 269      |
# |    time_elapsed    | 331      |
# |    total_timesteps | 89184    |
# | train/             |          |
# |    actor_loss      | -4.64    |
# |    critic_loss     | 0.92     |
# |    ent_coef        | 0.0625   |
# |    ent_coef_loss   | -1.56    |
# |    learning_rate   | 0.0006   |
# |    n_updates       | 4948     |
# ---------------------------------
# Eval num_timesteps=96000, episode_reward=-25.74 +/- 14.56
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -25.7    |
# | time/              |          |
# |    total_timesteps | 96000    |
# | train/             |          |
# |    actor_loss      | -5.12    |
# |    critic_loss     | 0.889    |
# |    ent_coef        | 0.0545   |
# |    ent_coef_loss   | -1.94    |
# |    learning_rate   | 0.00059  |
# |    n_updates       | 5374     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 742      |
# |    ep_rew_mean     | -68.6    |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 261      |
# |    time_elapsed    | 373      |
# |    total_timesteps | 97760    |
# | train/             |          |
# |    actor_loss      | -6.81    |
# |    critic_loss     | 0.695    |
# |    ent_coef        | 0.0529   |
# |    ent_coef_loss   | -2.17    |
# |    learning_rate   | 0.000587 |
# |    n_updates       | 5484     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 776      |
# |    ep_rew_mean     | -63.5    |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 261      |
# |    time_elapsed    | 381      |
# |    total_timesteps | 99792    |
# | train/             |          |
# |    actor_loss      | -1.38    |
# |    critic_loss     | 1.08     |
# |    ent_coef        | 0.0509   |
# |    ent_coef_loss   | -2.1     |
# |    learning_rate   | 0.000584 |
# |    n_updates       | 5611     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 810      |
# |    ep_rew_mean     | -59.1    |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 262      |
# |    time_elapsed    | 388      |
# |    total_timesteps | 102016   |
# | train/             |          |
# |    actor_loss      | -8.38    |
# |    critic_loss     | 0.545    |
# |    ent_coef        | 0.0488   |
# |    ent_coef_loss   | -1.42    |
# |    learning_rate   | 0.000581 |
# |    n_updates       | 5750     |
# ---------------------------------
# Eval num_timesteps=104000, episode_reward=-7.78 +/- 16.46
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -7.78    |
# | time/              |          |
# |    total_timesteps | 104000   |
# | train/             |          |
# |    actor_loss      | -7.42    |
# |    critic_loss     | 0.728    |
# |    ent_coef        | 0.0472   |
# |    ent_coef_loss   | -0.939   |
# |    learning_rate   | 0.000578 |
# |    n_updates       | 5874     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 842      |
# |    ep_rew_mean     | -55.9    |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 257      |
# |    time_elapsed    | 408      |
# |    total_timesteps | 105184   |
# | train/             |          |
# |    actor_loss      | -4.8     |
# |    critic_loss     | 0.679    |
# |    ent_coef        | 0.0463   |
# |    ent_coef_loss   | -2.02    |
# |    learning_rate   | 0.000576 |
# |    n_updates       | 5948     |
# ---------------------------------
# Eval num_timesteps=112000, episode_reward=-18.50 +/- 15.36
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -18.5    |
# | time/              |          |
# |    total_timesteps | 112000   |
# | train/             |          |
# |    actor_loss      | -3.86    |
# |    critic_loss     | 0.937    |
# |    ent_coef        | 0.0407   |
# |    ent_coef_loss   | -2.22    |
# |    learning_rate   | 0.000567 |
# |    n_updates       | 6374     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 874      |
# |    ep_rew_mean     | -50.4    |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 253      |
# |    time_elapsed    | 449      |
# |    total_timesteps | 113760   |
# | train/             |          |
# |    actor_loss      | -4.3     |
# |    critic_loss     | 0.501    |
# |    ent_coef        | 0.039    |
# |    ent_coef_loss   | -2.41    |
# |    learning_rate   | 0.000564 |
# |    n_updates       | 6484     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 906      |
# |    ep_rew_mean     | -45.2    |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 254      |
# |    time_elapsed    | 455      |
# |    total_timesteps | 115792   |
# | train/             |          |
# |    actor_loss      | -5.75    |
# |    critic_loss     | 0.525    |
# |    ent_coef        | 0.0373   |
# |    ent_coef_loss   | -1.29    |
# |    learning_rate   | 0.000561 |
# |    n_updates       | 6611     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 937      |
# |    ep_rew_mean     | -40.7    |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 255      |
# |    time_elapsed    | 462      |
# |    total_timesteps | 118016   |
# | train/             |          |
# |    actor_loss      | -7.05    |
# |    critic_loss     | 0.536    |
# |    ent_coef        | 0.0358   |
# |    ent_coef_loss   | -2.05    |
# |    learning_rate   | 0.000558 |
# |    n_updates       | 6750     |
# ---------------------------------
# Eval num_timesteps=120000, episode_reward=-17.16 +/- 10.29
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -17.2    |
# | time/              |          |
# |    total_timesteps | 120000   |
# | train/             |          |
# |    actor_loss      | -4.27    |
# |    critic_loss     | 0.779    |
# |    ent_coef        | 0.0342   |
# |    ent_coef_loss   | -0.0223  |
# |    learning_rate   | 0.000555 |
# |    n_updates       | 6874     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 965      |
# |    ep_rew_mean     | -38.8    |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 250      |
# |    time_elapsed    | 484      |
# |    total_timesteps | 121184   |
# | train/             |          |
# |    actor_loss      | -5.34    |
# |    critic_loss     | 0.647    |
# |    ent_coef        | 0.0335   |
# |    ent_coef_loss   | -1.9     |
# |    learning_rate   | 0.000553 |
# |    n_updates       | 6948     |
# ---------------------------------
# Eval num_timesteps=128000, episode_reward=-6.16 +/- 10.19
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -6.16    |
# | time/              |          |
# |    total_timesteps | 128000   |
# | train/             |          |
# |    actor_loss      | -7       |
# |    critic_loss     | 0.331    |
# |    ent_coef        | 0.0295   |
# |    ent_coef_loss   | -2.07    |
# |    learning_rate   | 0.000543 |
# |    n_updates       | 7374     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 990      |
# |    ep_rew_mean     | -37.7    |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 246      |
# |    time_elapsed    | 526      |
# |    total_timesteps | 129760   |
# | train/             |          |
# |    actor_loss      | -3.98    |
# |    critic_loss     | 0.747    |
# |    ent_coef        | 0.0285   |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 0.000541 |
# |    n_updates       | 7484     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -36.5    |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 246      |
# |    time_elapsed    | 533      |
# |    total_timesteps | 131792   |
# | train/             |          |
# |    actor_loss      | -9.22    |
# |    critic_loss     | 0.28     |
# |    ent_coef        | 0.0273   |
# |    ent_coef_loss   | -1.53    |
# |    learning_rate   | 0.000538 |
# |    n_updates       | 7611     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -36.9    |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 247      |
# |    time_elapsed    | 540      |
# |    total_timesteps | 134016   |
# | train/             |          |
# |    actor_loss      | 2.06     |
# |    critic_loss     | 1.49     |
# |    ent_coef        | 0.0261   |
# |    ent_coef_loss   | -0.41    |
# |    learning_rate   | 0.000534 |
# |    n_updates       | 7750     |
# ---------------------------------
# Eval num_timesteps=136000, episode_reward=-6.23 +/- 10.15
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -6.23    |
# | time/              |          |
# |    total_timesteps | 136000   |
# | train/             |          |
# |    actor_loss      | -3.74    |
# |    critic_loss     | 0.608    |
# |    ent_coef        | 0.025    |
# |    ent_coef_loss   | -2.78    |
# |    learning_rate   | 0.000531 |
# |    n_updates       | 7874     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -36.6    |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 244      |
# |    time_elapsed    | 561      |
# |    total_timesteps | 137184   |
# | train/             |          |
# |    actor_loss      | -7.32    |
# |    critic_loss     | 0.358    |
# |    ent_coef        | 0.0242   |
# |    ent_coef_loss   | -2.14    |
# |    learning_rate   | 0.00053  |
# |    n_updates       | 7948     |
# ---------------------------------
# Eval num_timesteps=144000, episode_reward=-41.77 +/- 14.64
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -41.8    |
# | time/              |          |
# |    total_timesteps | 144000   |
# | train/             |          |
# |    actor_loss      | -3.29    |
# |    critic_loss     | 0.892    |
# |    ent_coef        | 0.0216   |
# |    ent_coef_loss   | -0.873   |
# |    learning_rate   | 0.00052  |
# |    n_updates       | 8374     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -36.7    |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 242      |
# |    time_elapsed    | 600      |
# |    total_timesteps | 145760   |
# | train/             |          |
# |    actor_loss      | -4.36    |
# |    critic_loss     | 0.54     |
# |    ent_coef        | 0.0208   |
# |    ent_coef_loss   | -1.81    |
# |    learning_rate   | 0.000517 |
# |    n_updates       | 8484     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -36      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 243      |
# |    time_elapsed    | 607      |
# |    total_timesteps | 147792   |
# | train/             |          |
# |    actor_loss      | 0.0787   |
# |    critic_loss     | 0.783    |
# |    ent_coef        | 0.0201   |
# |    ent_coef_loss   | -2.34    |
# |    learning_rate   | 0.000514 |
# |    n_updates       | 8611     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -34.1    |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 244      |
# |    time_elapsed    | 613      |
# |    total_timesteps | 150016   |
# | train/             |          |
# |    actor_loss      | -0.0126  |
# |    critic_loss     | 0.632    |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.000511 |
# |    n_updates       | 8750     |
# ---------------------------------
# Eval num_timesteps=152000, episode_reward=-22.70 +/- 27.49
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -22.7    |
# | time/              |          |
# |    total_timesteps | 152000   |
# | train/             |          |
# |    actor_loss      | -5.7     |
# |    critic_loss     | 0.45     |
# |    ent_coef        | 0.0186   |
# |    ent_coef_loss   | -0.991   |
# |    learning_rate   | 0.000508 |
# |    n_updates       | 8874     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -32.8    |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 241      |
# |    time_elapsed    | 634      |
# |    total_timesteps | 153184   |
# | train/             |          |
# |    actor_loss      | 0.0191   |
# |    critic_loss     | 0.828    |
# |    ent_coef        | 0.0184   |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 0.000506 |
# |    n_updates       | 8948     |
# ---------------------------------
# Eval num_timesteps=160000, episode_reward=-15.24 +/- 21.98
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -15.2    |
# | time/              |          |
# |    total_timesteps | 160000   |
# | train/             |          |
# |    actor_loss      | -7.1     |
# |    critic_loss     | 0.461    |
# |    ent_coef        | 0.0175   |
# |    ent_coef_loss   | -0.0397  |
# |    learning_rate   | 0.000496 |
# |    n_updates       | 9374     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -31.5    |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 240      |
# |    time_elapsed    | 671      |
# |    total_timesteps | 161760   |
# | train/             |          |
# |    actor_loss      | -7.19    |
# |    critic_loss     | 0.343    |
# |    ent_coef        | 0.0172   |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 0.000494 |
# |    n_updates       | 9484     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -30.1    |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 241      |
# |    time_elapsed    | 677      |
# |    total_timesteps | 163792   |
# | train/             |          |
# |    actor_loss      | -3.03    |
# |    critic_loss     | 0.659    |
# |    ent_coef        | 0.017    |
# |    ent_coef_loss   | -0.625   |
# |    learning_rate   | 0.000491 |
# |    n_updates       | 9611     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -28.4    |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 242      |
# ...
# | eval/              |          |
# |    mean_ep_length  | 992      |
# |    mean_reward     | 20.4     |
# | time/              |          |
# |    total_timesteps | 424000   |
# | train/             |          |
# |    actor_loss      | 5.2      |
# |    critic_loss     | 0.21     |
# |    ent_coef        | 0.006    |
# |    ent_coef_loss   | -1.44    |
# |    learning_rate   | 0.000111 |
# |    n_updates       | 25874    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 983      |
# |    ep_rew_mean     | 1.85     |
# | time/              |          |
# |    episodes        | 552      |
# |    fps             | 224      |
# |    time_elapsed    | 1918     |
# |    total_timesteps | 430688   |
# | train/             |          |
# |    actor_loss      | 4.49     |
# |    critic_loss     | 0.209    |
# |    ent_coef        | 0.00583  |
# |    ent_coef_loss   | 0.454    |
# |    learning_rate   | 0.000101 |
# |    n_updates       | 26292    |
# ---------------------------------
# Eval num_timesteps=432000, episode_reward=-13.56 +/- 8.17
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -13.6    |
# | time/              |          |
# |    total_timesteps | 432000   |
# | train/             |          |
# |    actor_loss      | 5.48     |
# |    critic_loss     | 0.26     |
# |    ent_coef        | 0.00581  |
# |    ent_coef_loss   | -0.297   |
# |    learning_rate   | 9.93e-05 |
# |    n_updates       | 26374    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 983      |
# |    ep_rew_mean     | 1.18     |
# | time/              |          |
# |    episodes        | 556      |
# |    fps             | 223      |
# |    time_elapsed    | 1948     |
# |    total_timesteps | 434832   |
# | train/             |          |
# |    actor_loss      | 2.44     |
# |    critic_loss     | 0.0498   |
# |    ent_coef        | 0.00579  |
# |    ent_coef_loss   | -0.775   |
# |    learning_rate   | 9.52e-05 |
# |    n_updates       | 26551    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 983      |
# |    ep_rew_mean     | 0.399    |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 223      |
# |    time_elapsed    | 1954     |
# |    total_timesteps | 436832   |
# | train/             |          |
# |    actor_loss      | 5.39     |
# |    critic_loss     | 0.116    |
# |    ent_coef        | 0.00577  |
# |    ent_coef_loss   | -0.746   |
# |    learning_rate   | 9.22e-05 |
# |    n_updates       | 26676    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 983      |
# |    ep_rew_mean     | -0.196   |
# | time/              |          |
# |    episodes        | 564      |
# |    fps             | 223      |
# |    time_elapsed    | 1961     |
# |    total_timesteps | 439344   |
# | train/             |          |
# |    actor_loss      | 3.6      |
# |    critic_loss     | 0.045    |
# |    ent_coef        | 0.00574  |
# |    ent_coef_loss   | -0.715   |
# |    learning_rate   | 8.86e-05 |
# |    n_updates       | 26833    |
# ---------------------------------
# Eval num_timesteps=440000, episode_reward=-7.75 +/- 15.45
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -7.75    |
# | time/              |          |
# |    total_timesteps | 440000   |
# | train/             |          |
# |    actor_loss      | 0.0124   |
# |    critic_loss     | 0.0696   |
# |    ent_coef        | 0.00574  |
# |    ent_coef_loss   | -1.42    |
# |    learning_rate   | 8.76e-05 |
# |    n_updates       | 26874    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 979      |
# |    ep_rew_mean     | 1.12     |
# | time/              |          |
# |    episodes        | 568      |
# |    fps             | 223      |
# |    time_elapsed    | 1997     |
# |    total_timesteps | 446688   |
# | train/             |          |
# |    actor_loss      | 2.73     |
# |    critic_loss     | 0.143    |
# |    ent_coef        | 0.00568  |
# |    ent_coef_loss   | 0.581    |
# |    learning_rate   | 7.79e-05 |
# |    n_updates       | 27292    |
# ---------------------------------
# Eval num_timesteps=448000, episode_reward=-15.51 +/- 13.85
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -15.5    |
# | time/              |          |
# |    total_timesteps | 448000   |
# | train/             |          |
# |    actor_loss      | 1.14     |
# |    critic_loss     | 0.135    |
# |    ent_coef        | 0.00567  |
# |    ent_coef_loss   | -0.0935  |
# |    learning_rate   | 7.59e-05 |
# |    n_updates       | 27374    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 979      |
# |    ep_rew_mean     | 0.654    |
# | time/              |          |
# |    episodes        | 572      |
# |    fps             | 222      |
# |    time_elapsed    | 2026     |
# |    total_timesteps | 450832   |
# | train/             |          |
# |    actor_loss      | 2.48     |
# |    critic_loss     | 0.386    |
# |    ent_coef        | 0.00565  |
# |    ent_coef_loss   | 0.57     |
# |    learning_rate   | 7.18e-05 |
# |    n_updates       | 27551    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 980      |
# |    ep_rew_mean     | 0.0421   |
# | time/              |          |
# |    episodes        | 576      |
# |    fps             | 222      |
# |    time_elapsed    | 2032     |
# |    total_timesteps | 452832   |
# | train/             |          |
# |    actor_loss      | 5.48     |
# |    critic_loss     | 0.178    |
# |    ent_coef        | 0.00562  |
# |    ent_coef_loss   | -1.24    |
# |    learning_rate   | 6.89e-05 |
# |    n_updates       | 27676    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 983      |
# |    ep_rew_mean     | -2.39    |
# | time/              |          |
# |    episodes        | 580      |
# |    fps             | 223      |
# |    time_elapsed    | 2038     |
# |    total_timesteps | 455344   |
# | train/             |          |
# |    actor_loss      | 2.32     |
# |    critic_loss     | 0.0538   |
# |    ent_coef        | 0.00558  |
# |    ent_coef_loss   | -1.27    |
# |    learning_rate   | 6.52e-05 |
# |    n_updates       | 27833    |
# ---------------------------------
# Eval num_timesteps=456000, episode_reward=12.39 +/- 78.35
# Episode length: 948.40 +/- 103.20
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 948      |
# |    mean_reward     | 12.4     |
# | time/              |          |
# |    total_timesteps | 456000   |
# | train/             |          |
# |    actor_loss      | 4.96     |
# |    critic_loss     | 0.0921   |
# |    ent_coef        | 0.00558  |
# |    ent_coef_loss   | -1.13    |
# |    learning_rate   | 6.43e-05 |
# |    n_updates       | 27874    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 983      |
# |    ep_rew_mean     | -2.67    |
# | time/              |          |
# |    episodes        | 584      |
# |    fps             | 223      |
# |    time_elapsed    | 2070     |
# |    total_timesteps | 462688   |
# | train/             |          |
# |    actor_loss      | 6.21     |
# |    critic_loss     | 0.208    |
# |    ent_coef        | 0.00551  |
# |    ent_coef_loss   | -0.453   |
# |    learning_rate   | 5.45e-05 |
# |    n_updates       | 28292    |
# ---------------------------------
# Eval num_timesteps=464000, episode_reward=-9.96 +/- 29.57
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -9.96    |
# | time/              |          |
# |    total_timesteps | 464000   |
# | train/             |          |
# |    actor_loss      | 1.19     |
# |    critic_loss     | 0.216    |
# |    ent_coef        | 0.0055   |
# |    ent_coef_loss   | -0.496   |
# |    learning_rate   | 5.26e-05 |
# |    n_updates       | 28374    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 981      |
# |    ep_rew_mean     | -3.07    |
# | time/              |          |
# |    episodes        | 588      |
# |    fps             | 222      |
# |    time_elapsed    | 2094     |
# |    total_timesteps | 465856   |
# | train/             |          |
# |    actor_loss      | 3.43     |
# |    critic_loss     | 0.0423   |
# |    ent_coef        | 0.00547  |
# |    ent_coef_loss   | -1.51    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 28490    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 984      |
# |    ep_rew_mean     | -6.59    |
# | time/              |          |
# |    episodes        | 592      |
# |    fps             | 222      |
# |    time_elapsed    | 2102     |
# |    total_timesteps | 468096   |
# | train/             |          |
# |    actor_loss      | 5.43     |
# |    critic_loss     | 0.0959   |
# |    ent_coef        | 0.00546  |
# |    ent_coef_loss   | -2.46    |
# |    learning_rate   | 4.66e-05 |
# |    n_updates       | 28630    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 988      |
# |    ep_rew_mean     | -8.34    |
# | time/              |          |
# |    episodes        | 596      |
# |    fps             | 223      |
# |    time_elapsed    | 2108     |
# |    total_timesteps | 470496   |
# | train/             |          |
# |    actor_loss      | 2.95     |
# |    critic_loss     | 0.0489   |
# |    ent_coef        | 0.00545  |
# |    ent_coef_loss   | 0.551    |
# |    learning_rate   | 4.31e-05 |
# |    n_updates       | 28780    |
# ---------------------------------
# Eval num_timesteps=472000, episode_reward=-1.95 +/- 13.15
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -1.95    |
# | time/              |          |
# |    total_timesteps | 472000   |
# | train/             |          |
# |    actor_loss      | 2.67     |
# |    critic_loss     | 0.227    |
# |    ent_coef        | 0.00544  |
# |    ent_coef_loss   | -0.998   |
# |    learning_rate   | 4.09e-05 |
# |    n_updates       | 28874    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 981      |
# |    ep_rew_mean     | -5.45    |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 222      |
# |    time_elapsed    | 2126     |
# |    total_timesteps | 472208   |
# | train/             |          |
# |    actor_loss      | 5.04     |
# |    critic_loss     | 0.155    |
# |    ent_coef        | 0.00544  |
# |    ent_coef_loss   | -0.326   |
# |    learning_rate   | 4.06e-05 |
# |    n_updates       | 28887    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 981      |
# |    ep_rew_mean     | -5.53    |
# | time/              |          |
# |    episodes        | 604      |
# |    fps             | 223      |
# |    time_elapsed    | 2146     |
# |    total_timesteps | 479440   |
# | train/             |          |
# |    actor_loss      | 3.69     |
# |    critic_loss     | 0.235    |
# |    ent_coef        | 0.00543  |
# |    ent_coef_loss   | -0.438   |
# |    learning_rate   | 3e-05    |
# |    n_updates       | 29339    |
# ---------------------------------
# Eval num_timesteps=480000, episode_reward=0.95 +/- 22.97
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 0.954    |
# | time/              |          |
# |    total_timesteps | 480000   |
# | train/             |          |
# |    actor_loss      | 4.13     |
# |    critic_loss     | 0.32     |
# |    ent_coef        | 0.00542  |
# |    ent_coef_loss   | 2.29     |
# |    learning_rate   | 2.92e-05 |
# |    n_updates       | 29374    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 981      |
# |    ep_rew_mean     | -4.76    |
# | time/              |          |
# |    episodes        | 608      |
# |    fps             | 222      |
# |    time_elapsed    | 2175     |
# |    total_timesteps | 484096   |
# | train/             |          |
# |    actor_loss      | 5.24     |
# |    critic_loss     | 0.272    |
# |    ent_coef        | 0.00541  |
# |    ent_coef_loss   | -1.58    |
# |    learning_rate   | 2.32e-05 |
# |    n_updates       | 29630    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 981      |
# |    ep_rew_mean     | -3.16    |
# | time/              |          |
# |    episodes        | 612      |
# |    fps             | 222      |
# |    time_elapsed    | 2182     |
# |    total_timesteps | 486496   |
# | train/             |          |
# |    actor_loss      | 5.87     |
# |    critic_loss     | 0.497    |
# |    ent_coef        | 0.00541  |
# |    ent_coef_loss   | -0.122   |
# |    learning_rate   | 1.97e-05 |
# |    n_updates       | 29780    |
# ---------------------------------
# Eval num_timesteps=488000, episode_reward=-10.91 +/- 11.48
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | -10.9    |
# | time/              |          |
# |    total_timesteps | 488000   |
# | train/             |          |
# |    actor_loss      | 6.44     |
# |    critic_loss     | 0.306    |
# |    ent_coef        | 0.0054   |
# |    ent_coef_loss   | -1.99    |
# |    learning_rate   | 1.75e-05 |
# |    n_updates       | 29874    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 981      |
# |    ep_rew_mean     | -3.54    |
# | time/              |          |
# |    episodes        | 616      |
# |    fps             | 221      |
# |    time_elapsed    | 2204     |
# |    total_timesteps | 488208   |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 0.0832   |
# |    ent_coef        | 0.0054   |
# |    ent_coef_loss   | -0.328   |
# |    learning_rate   | 1.72e-05 |
# |    n_updates       | 29887    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 982      |
# |    ep_rew_mean     | -4.88    |
# | time/              |          |
# |    episodes        | 620      |
# |    fps             | 222      |
# |    time_elapsed    | 2224     |
# |    total_timesteps | 495440   |
# | train/             |          |
# |    actor_loss      | 4.8      |
# |    critic_loss     | 0.142    |
# |    ent_coef        | 0.00539  |
# |    ent_coef_loss   | -0.764   |
# |    learning_rate   | 6.68e-06 |
# |    n_updates       | 30339    |
# ---------------------------------
# Eval num_timesteps=496000, episode_reward=51.46 +/- 79.50
# Episode length: 913.20 +/- 173.60
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 913      |
# |    mean_reward     | 51.5     |
# | time/              |          |
# |    total_timesteps | 496000   |
# | train/             |          |
# |    actor_loss      | 4.55     |
# |    critic_loss     | 0.21     |
# |    ent_coef        | 0.00539  |
# |    ent_coef_loss   | 0.582    |
# |    learning_rate   | 5.86e-06 |
# |    n_updates       | 30374    |
# ---------------------------------
# New best mean reward!

# %%
model.save("data/policies/LunarLander-v2#tqc#training")
del model

# %%
model = TQC.load("logs/tqc/best_model", env=train_env)

# %%
model.learn(total_timesteps=int(1e6), callback=eval_callback)
# Out:
# Logging to ./runs/sac_lunar_tensorboard/SAC_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 69.8     |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 4455     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1152     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 80       |
# |    ep_rew_mean     | -162     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 4498     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1584     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.6     |
# |    ep_rew_mean     | -195     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 4471     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1872     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.2     |
# |    ep_rew_mean     | -195     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 4466     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2464     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.7     |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 4465     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2736     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.2     |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 4412     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2816     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.7     |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 4475     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3568     |
# ---------------------------------
# Eval num_timesteps=4000, episode_reward=158.24 +/- 128.88
# Episode length: 607.00 +/- 327.90
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 607      |
# |    mean_reward     | 158      |
# | time/              |          |
# |    total_timesteps | 4000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.6     |
# |    ep_rew_mean     | -201     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 529      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 4032     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.2     |
# |    ep_rew_mean     | -211     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 582      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 4496     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.2     |
# |    ep_rew_mean     | -221     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 605      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 4704     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 653      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 5136     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 713      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 5696     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -215     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 762      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 6176     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -214     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 812      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 6672     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -215     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 823      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 6784     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 873      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 7280     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 939      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 7968     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -211     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 964      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 8240     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -213     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 990      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 8528     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -219     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 1041     |
# |    time_elapsed    | 8        |
# |    total_timesteps | 9104     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -215     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 1072     |
# |    time_elapsed    | 8        |
# |    total_timesteps | 9456     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -212     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 1083     |
# |    time_elapsed    | 8        |
# |    total_timesteps | 9584     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -205     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 1092     |
# |    time_elapsed    | 9        |
# |    total_timesteps | 10240    |
# | train/             |          |
# |    actor_loss      | -22      |
# |    critic_loss     | 19.9     |
# |    ent_coef        | 0.0305   |
# |    ent_coef_loss   | 7.83     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 14388    |
# ---------------------------------
# Eval num_timesteps=12000, episode_reward=96.27 +/- 121.17
# Episode length: 812.60 +/- 276.04
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 813      |
# |    mean_reward     | 96.3     |
# | time/              |          |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -22.7    |
# |    critic_loss     | 28.3     |
# |    ent_coef        | 0.0409   |
# |    ent_coef_loss   | 7.67     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 14498    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -197     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 532      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 13104    |
# | train/             |          |
# |    actor_loss      | -28.8    |
# |    critic_loss     | 18.6     |
# |    ent_coef        | 0.0455   |
# |    ent_coef_loss   | 4.01     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 14567    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | -186     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 476      |
# |    time_elapsed    | 39       |
# |    total_timesteps | 18688    |
# | train/             |          |
# |    actor_loss      | -19.2    |
# |    critic_loss     | 20.1     |
# |    ent_coef        | 0.0616   |
# |    ent_coef_loss   | 2.12     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 14916    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=207.58 +/- 86.15
# Episode length: 290.40 +/- 97.84
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 290      |
# |    mean_reward     | 208      |
# | time/              |          |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -16.9    |
# |    critic_loss     | 9.11     |
# |    ent_coef        | 0.0644   |
# |    ent_coef_loss   | 1.23     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 14998    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 138      |
# |    ep_rew_mean     | -183     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 435      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 20272    |
# | train/             |          |
# |    actor_loss      | -23.9    |
# |    critic_loss     | 8.42     |
# |    ent_coef        | 0.0648   |
# |    ent_coef_loss   | 0.358    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 15015    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 157      |
# |    ep_rew_mean     | -166     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 432      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 21200    |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 6.49     |
# |    ent_coef        | 0.0657   |
# |    ent_coef_loss   | 0.165    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 15073    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | -153     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 418      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 25456    |
# | train/             |          |
# |    actor_loss      | -21.4    |
# |    critic_loss     | 21.6     |
# |    ent_coef        | 0.0681   |
# |    ent_coef_loss   | -0.0956  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 15339    |
# ---------------------------------
# Eval num_timesteps=28000, episode_reward=8.83 +/- 15.63
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 8.83     |
# | time/              |          |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -22.4    |
# |    critic_loss     | 21.1     |
# |    ent_coef        | 0.0671   |
# |    ent_coef_loss   | 0.338    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 15498    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | -141     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 341      |
# |    time_elapsed    | 91       |
# |    total_timesteps | 31360    |
# | train/             |          |
# |    actor_loss      | -16.7    |
# |    critic_loss     | 7.26     |
# |    ent_coef        | 0.064    |
# |    ent_coef_loss   | -0.928   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 15708    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | -131     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 334      |
# |    time_elapsed    | 103      |
# |    total_timesteps | 34512    |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 13.1     |
# |    ent_coef        | 0.0611   |
# |    ent_coef_loss   | 0.0778   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 15905    |
# ---------------------------------
# Eval num_timesteps=36000, episode_reward=125.33 +/- 70.82
# Episode length: 834.60 +/- 190.72
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 835      |
# |    mean_reward     | 125      |
# | time/              |          |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 45.3     |
# |    ent_coef        | 0.0599   |
# |    ent_coef_loss   | -0.0209  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 15998    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 276      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 303      |
# |    time_elapsed    | 120      |
# |    total_timesteps | 36560    |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 4.62     |
# |    ent_coef        | 0.0594   |
# |    ent_coef_loss   | -0.547   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 16033    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 311      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 307      |
# |    time_elapsed    | 129      |
# |    total_timesteps | 39920    |
# | train/             |          |
# |    actor_loss      | -13.9    |
# |    critic_loss     | 33       |
# |    ent_coef        | 0.0552   |
# |    ent_coef_loss   | -0.5     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 16243    |
# ---------------------------------
# Eval num_timesteps=44000, episode_reward=0.63 +/- 24.99
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 0.628    |
# | time/              |          |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 3.8      |
# |    ent_coef        | 0.0504   |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 16498    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 341      |
# |    ep_rew_mean     | -97.9    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 276      |
# |    time_elapsed    | 163      |
# |    total_timesteps | 45232    |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.049    |
# |    ent_coef_loss   | -1.15    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 16575    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 366      |
# |    ep_rew_mean     | -79.2    |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 276      |
# |    time_elapsed    | 166      |
# |    total_timesteps | 46224    |
# | train/             |          |
# |    actor_loss      | -13.4    |
# |    critic_loss     | 32.5     |
# |    ent_coef        | 0.0479   |
# |    ent_coef_loss   | 0.0455   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 16637    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 396      |
# |    ep_rew_mean     | -62.5    |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 279      |
# |    time_elapsed    | 171      |
# |    total_timesteps | 48128    |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 15.1     |
# |    ent_coef        | 0.0468   |
# |    ent_coef_loss   | -0.602   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 16756    |
# ---------------------------------
# Eval num_timesteps=52000, episode_reward=127.47 +/- 189.89
# Episode length: 672.80 +/- 154.26
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 673      |
# |    mean_reward     | 127      |
# | time/              |          |
# |    total_timesteps | 52000    |
# | train/             |          |
# |    actor_loss      | -11.8    |
# |    critic_loss     | 29.9     |
# |    ent_coef        | 0.0465   |
# |    ent_coef_loss   | 0.611    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 16998    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 426      |
# |    ep_rew_mean     | -51      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 274      |
# |    time_elapsed    | 194      |
# |    total_timesteps | 53472    |
# | train/             |          |
# |    actor_loss      | -16.4    |
# |    critic_loss     | 32.7     |
# |    ent_coef        | 0.0456   |
# |    ent_coef_loss   | 0.347    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 17090    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 453      |
# |    ep_rew_mean     | -36.9    |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 276      |
# |    time_elapsed    | 209      |
# |    total_timesteps | 58080    |
# | train/             |          |
# |    actor_loss      | -15.8    |
# |    critic_loss     | 3.59     |
# |    ent_coef        | 0.0431   |
# |    ent_coef_loss   | -0.265   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 17378    |
# ---------------------------------
# Eval num_timesteps=60000, episode_reward=59.90 +/- 77.07
# Episode length: 982.00 +/- 31.69
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 982      |
# |    mean_reward     | 59.9     |
# | time/              |          |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 5.25     |
# |    ent_coef        | 0.0439   |
# |    ent_coef_loss   | 0.372    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 17498    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 483      |
# |    ep_rew_mean     | -24.5    |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 261      |
# |    time_elapsed    | 231      |
# |    total_timesteps | 60384    |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 24       |
# |    ent_coef        | 0.0437   |
# |    ent_coef_loss   | -1.15    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 17522    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 515      |
# |    ep_rew_mean     | -12.5    |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 262      |
# |    time_elapsed    | 237      |
# |    total_timesteps | 62368    |
# | train/             |          |
# |    actor_loss      | -16.7    |
# |    critic_loss     | 3.91     |
# |    ent_coef        | 0.0443   |
# |    ent_coef_loss   | 1.62     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 17646    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 543      |
# |    ep_rew_mean     | 1.65     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 266      |
# |    time_elapsed    | 254      |
# |    total_timesteps | 67760    |
# | train/             |          |
# |    actor_loss      | -11.1    |
# |    critic_loss     | 3.77     |
# |    ent_coef        | 0.0433   |
# |    ent_coef_loss   | 0.284    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 17983    |
# ---------------------------------
# Eval num_timesteps=68000, episode_reward=68.44 +/- 80.12
# Episode length: 938.20 +/- 109.22
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 938      |
# |    mean_reward     | 68.4     |
# | time/              |          |
# |    total_timesteps | 68000    |
# | train/             |          |
# |    actor_loss      | -13.9    |
# |    critic_loss     | 8.24     |
# |    ent_coef        | 0.0433   |
# |    ent_coef_loss   | -0.742   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 17998    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 575      |
# |    ep_rew_mean     | 14.6     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 250      |
# |    time_elapsed    | 282      |
# |    total_timesteps | 70816    |
# | train/             |          |
# |    actor_loss      | -12.3    |
# |    critic_loss     | 7.97     |
# |    ent_coef        | 0.0443   |
# |    ent_coef_loss   | -0.37    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 18174    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 603      |
# |    ep_rew_mean     | 26.1     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 251      |
# |    time_elapsed    | 293      |
# |    total_timesteps | 73952    |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 1.98     |
# |    ent_coef        | 0.0436   |
# |    ent_coef_loss   | 0.858    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 18370    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 633      |
# |    ep_rew_mean     | 36.2     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 252      |
# |    time_elapsed    | 298      |
# |    total_timesteps | 75472    |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.044    |
# |    ent_coef_loss   | 0.26     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 18465    |
# ---------------------------------
# Eval num_timesteps=76000, episode_reward=-80.20 +/- 146.74
# Episode length: 775.60 +/- 202.91
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 776      |
# |    mean_reward     | -80.2    |
# | time/              |          |
# |    total_timesteps | 76000    |
# | train/             |          |
# |    actor_loss      | -15.9    |
# |    critic_loss     | 2.86     |
# |    ent_coef        | 0.0449   |
# |    ent_coef_loss   | 1.52     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 18498    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 658      |
# |    ep_rew_mean     | 50.5     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 246      |
# |    time_elapsed    | 314      |
# |    total_timesteps | 77680    |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 26.8     |
# |    ent_coef        | 0.0511   |
# |    ent_coef_loss   | 0.417    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 18603    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 677      |
# |    ep_rew_mean     | 58.6     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 249      |
# |    time_elapsed    | 325      |
# |    total_timesteps | 81184    |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0568   |
# |    ent_coef_loss   | -0.222   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 18822    |
# ---------------------------------
# Eval num_timesteps=84000, episode_reward=29.34 +/- 103.31
# Episode length: 948.00 +/- 78.66
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 948      |
# |    mean_reward     | 29.3     |
# | time/              |          |
# |    total_timesteps | 84000    |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 15.3     |
# |    ent_coef        | 0.0607   |
# |    ent_coef_loss   | 0.617    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 18998    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 709      |
# |    ep_rew_mean     | 64.3     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 242      |
# |    time_elapsed    | 362      |
# |    total_timesteps | 87952    |
# | train/             |          |
# |    actor_loss      | -12.8    |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.0619   |
# |    ent_coef_loss   | 0.394    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 19245    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 731      |
# |    ep_rew_mean     | 75.3     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 243      |
# |    time_elapsed    | 367      |
# |    total_timesteps | 89616    |
# | train/             |          |
# |    actor_loss      | -9.91    |
# |    critic_loss     | 3        |
# |    ent_coef        | 0.0626   |
# |    ent_coef_loss   | -1.81    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 19349    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 757      |
# |    ep_rew_mean     | 79.9     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 244      |
# |    time_elapsed    | 369      |
# |    total_timesteps | 90512    |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 9.32     |
# |    ent_coef        | 0.0606   |
# |    ent_coef_loss   | 0.51     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 19405    |
# ---------------------------------
# Eval num_timesteps=92000, episode_reward=215.37 +/- 19.18
# Episode length: 506.60 +/- 164.59
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 507      |
# |    mean_reward     | 215      |
# | time/              |          |
# |    total_timesteps | 92000    |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 15.4     |
# |    ent_coef        | 0.0618   |
# |    ent_coef_loss   | -0.0103  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 19498    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 783      |
# |    ep_rew_mean     | 80.7     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 243      |
# |    time_elapsed    | 379      |
# |    total_timesteps | 92464    |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 19.8     |
# |    ent_coef        | 0.0614   |
# |    ent_coef_loss   | -0.622   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 19527    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 787      |
# |    ep_rew_mean     | 84.3     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 246      |
# |    time_elapsed    | 384      |
# |    total_timesteps | 94544    |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 21.3     |
# |    ent_coef        | 0.0623   |
# |    ent_coef_loss   | 0.642    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 19657    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 782      |
# |    ep_rew_mean     | 93.9     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 249      |
# |    time_elapsed    | 391      |
# |    total_timesteps | 97952    |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 24.6     |
# |    ent_coef        | 0.0641   |
# |    ent_coef_loss   | 0.156    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 19870    |
# ---------------------------------
# Eval num_timesteps=100000, episode_reward=199.18 +/- 97.67
# Episode length: 579.60 +/- 315.65
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 580      |
# |    mean_reward     | 199      |
# | time/              |          |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 28.8     |
# |    ent_coef        | 0.0682   |
# |    ent_coef_loss   | -0.459   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 19998    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 782      |
# |    ep_rew_mean     | 94.3     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 246      |
# |    time_elapsed    | 406      |
# |    total_timesteps | 100464   |
# | train/             |          |
# |    actor_loss      | -14.4    |
# |    critic_loss     | 28.2     |
# |    ent_coef        | 0.0689   |
# |    ent_coef_loss   | 0.701    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 20027    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 774      |
# |    ep_rew_mean     | 99.6     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 248      |
# |    time_elapsed    | 414      |
# |    total_timesteps | 103056   |
# | train/             |          |
# |    actor_loss      | -14.7    |
# |    critic_loss     | 10.4     |
# |    ent_coef        | 0.0609   |
# |    ent_coef_loss   | -0.727   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 20189    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 775      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 249      |
# |    time_elapsed    | 416      |
# |    total_timesteps | 103984   |
# | train/             |          |
# |    actor_loss      | -18.9    |
# |    critic_loss     | 18.5     |
# |    ent_coef        | 0.0574   |
# |    ent_coef_loss   | -1.51    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 20247    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 764      |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 251      |
# |    time_elapsed    | 421      |
# |    total_timesteps | 105952   |
# | train/             |          |
# |    actor_loss      | -13.7    |
# |    critic_loss     | 23.1     |
# |    ent_coef        | 0.055    |
# |    ent_coef_loss   | -0.121   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 20370    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 737      |
# |    ep_rew_mean     | 117      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 252      |
# |    time_elapsed    | 422      |
# |    total_timesteps | 106528   |
# | train/             |          |
# |    actor_loss      | -16      |
# |    critic_loss     | 2.72     |
# |    ent_coef        | 0.0554   |
# |    ent_coef_loss   | -0.527   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 20406    |
# ---------------------------------
# Eval num_timesteps=108000, episode_reward=141.09 +/- 79.34
# Episode length: 731.60 +/- 198.24
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 732      |
# |    mean_reward     | 141      |
# | time/              |          |
# |    total_timesteps | 108000   |
# | train/             |          |
# |    actor_loss      | -19.7    |
# |    critic_loss     | 1.41     |
# |    ent_coef        | 0.0539   |
# |    ent_coef_loss   | 0.0252   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 20498    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 706      |
# |    ep_rew_mean     | 124      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 248      |
# |    time_elapsed    | 435      |
# |    total_timesteps | 108032   |
# | train/             |          |
# |    actor_loss      | -12.8    |
# |    critic_loss     | 20.6     |
# |    ent_coef        | 0.0539   |
# |    ent_coef_loss   | 0.168    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 20500    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 682      |
# |    ep_rew_mean     | 127      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 250      |
# |    time_elapsed    | 440      |
# |    total_timesteps | 110272   |
# | train/             |          |
# |    actor_loss      | -19.6    |
# |    critic_loss     | 13       |
# |    ent_coef        | 0.0535   |
# |    ent_coef_loss   | -0.808   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 20640    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 679      |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 251      |
# |    time_elapsed    | 443      |
# |    total_timesteps | 111648   |
# | train/             |          |
# |    actor_loss      | -21      |
# |    critic_loss     | 7.75     |
# |    ent_coef        | 0.053    |
# |    ent_coef_loss   | 0.39     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 20726    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 662      |
# |    ep_rew_mean     | 132      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 254      |
# |    time_elapsed    | 448      |
# |    total_timesteps | 114032   |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 16.6     |
# |    ent_coef        | 0.0536   |
# |    ent_coef_loss   | -0.266   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 20875    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 644      |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 255      |
# |    time_elapsed    | 452      |
# |    total_timesteps | 115552   |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 9.97     |
# |    ent_coef        | 0.0519   |
# |    ent_coef_loss   | -0.498   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 20970    |
# ---------------------------------
# Eval num_timesteps=116000, episode_reward=47.07 +/- 56.58
# Episode length: 927.20 +/- 145.60
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 927      |
# |    mean_reward     | 47.1     |
# | time/              |          |
# |    total_timesteps | 116000   |
# | train/             |          |
# |    actor_loss      | -20.1    |
# |    critic_loss     | 15.4     |
# |    ent_coef        | 0.0511   |
# |    ent_coef_loss   | -0.683   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 20998    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 635      |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 251      |
# |    time_elapsed    | 468      |
# |    total_timesteps | 118032   |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 8.53     |
# |    ent_coef        | 0.0522   |
# |    ent_coef_loss   | -0.0186  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 21125    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 620      |
# |    ep_rew_mean     | 145      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 254      |
# |    time_elapsed    | 477      |
# |    total_timesteps | 121488   |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 3.45     |
# |    ent_coef        | 0.054    |
# |    ent_coef_loss   | -0.0553  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 21341    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 599      |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 254      |
# |    time_elapsed    | 477      |
# |    total_timesteps | 121696   |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 1.89     |
# |    ent_coef        | 0.0541   |
# |    ent_coef_loss   | -0.00753 |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 21354    |
# ---------------------------------
# Eval num_timesteps=124000, episode_reward=110.38 +/- 210.26
# Episode length: 469.80 +/- 326.85
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 470      |
# |    mean_reward     | 110      |
# | time/              |          |
# |    total_timesteps | 124000   |
# | train/             |          |
# |    actor_loss      | -21.3    |
# |    critic_loss     | 4.8      |
# |    ent_coef        | 0.0558   |
# |    ent_coef_loss   | 0.808    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 21498    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 588      |
# |    ep_rew_mean     | 155      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 254      |
# |    time_elapsed    | 488      |
# |    total_timesteps | 124256   |
# | train/             |          |
# |    actor_loss      | -18.7    |
# |    critic_loss     | 4.91     |
# |    ent_coef        | 0.056    |
# |    ent_coef_loss   | -1.26    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 21514    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 574      |
# |    ep_rew_mean     | 159      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 255      |
# |    time_elapsed    | 490      |
# |    total_timesteps | 125280   |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 32.3     |
# |    ent_coef        | 0.0557   |
# |    ent_coef_loss   | 0.573    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 21578    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 562      |
# |    ep_rew_mean     | 165      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 257      |
# |    time_elapsed    | 496      |
# |    total_timesteps | 128032   |
# | train/             |          |
# |    actor_loss      | -20.9    |
# |    critic_loss     | 10.1     |
# |    ent_coef        | 0.0553   |
# |    ent_coef_loss   | -0.0358  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 21750    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 546      |
# |    ep_rew_mean     | 168      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 260      |
# |    time_elapsed    | 503      |
# |    total_timesteps | 130976   |
# | train/             |          |
# |    actor_loss      | -24.9    |
# |    critic_loss     | 15.5     |
# |    ent_coef        | 0.0545   |
# |    ent_coef_loss   | -0.63    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 21934    |
# ---------------------------------
# Eval num_timesteps=132000, episode_reward=87.67 +/- 129.55
# Episode length: 773.60 +/- 280.89
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 774      |
# |    mean_reward     | 87.7     |
# | time/              |          |
# |    total_timesteps | 132000   |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 9.88     |
# |    ent_coef        | 0.0547   |
# |    ent_coef_loss   | -0.213   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 21998    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 539      |
# |    ep_rew_mean     | 171      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 257      |
# |    time_elapsed    | 525      |
# |    total_timesteps | 135152   |
# | train/             |          |
# |    actor_loss      | -21.5    |
# |    critic_loss     | 2.63     |
# |    ent_coef        | 0.0527   |
# |    ent_coef_loss   | -0.792   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 22195    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 544      |
# |    ep_rew_mean     | 183      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 257      |
# |    time_elapsed    | 529      |
# |    total_timesteps | 136576   |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 5.79     |
# |    ent_coef        | 0.0514   |
# |    ent_coef_loss   | 1.28     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 22284    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 532      |
# |    ep_rew_mean     | 191      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 259      |
# |    time_elapsed    | 534      |
# |    total_timesteps | 138512   |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 3.82     |
# |    ent_coef        | 0.0498   |
# |    ent_coef_loss   | -1.05    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 22405    |
# ---------------------------------
# Eval num_timesteps=140000, episode_reward=186.97 +/- 32.61
# Episode length: 648.00 +/- 185.83
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 648      |
# |    mean_reward     | 187      |
# | time/              |          |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | -19.4    |
# |    critic_loss     | 3.69     |
# |    ent_coef        | 0.0486   |
# |    ent_coef_loss   | -0.867   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 22498    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 531      |
# |    ep_rew_mean     | 191      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 256      |
# |    time_elapsed    | 551      |
# |    total_timesteps | 141456   |
# | train/             |          |
# |    actor_loss      | -25      |
# |    critic_loss     | 18.4     |
# |    ent_coef        | 0.0486   |
# |    ent_coef_loss   | 0.185    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 22589    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 526      |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 257      |
# |    time_elapsed    | 555      |
# |    total_timesteps | 142976   |
# | train/             |          |
# |    actor_loss      | -22.9    |
# |    critic_loss     | 2.4      |
# |    ent_coef        | 0.0478   |
# |    ent_coef_loss   | 0.289    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 22684    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 519      |
# |    ep_rew_mean     | 201      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 258      |
# |    time_elapsed    | 557      |
# |    total_timesteps | 144128   |
# | train/             |          |
# |    actor_loss      | -23.1    |
# |    critic_loss     | 14.3     |
# |    ent_coef        | 0.0479   |
# |    ent_coef_loss   | -0.0843  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 22756    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 520      |
# |    ep_rew_mean     | 203      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 260      |
# |    time_elapsed    | 563      |
# |    total_timesteps | 146832   |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 10.9     |
# ...
# |    mean_ep_length  | 188      |
# |    mean_reward     | 279      |
# | time/              |          |
# |    total_timesteps | 980000   |
# | train/             |          |
# |    actor_loss      | -69.9    |
# |    critic_loss     | 4.57     |
# |    ent_coef        | 0.0353   |
# |    ent_coef_loss   | 0.138    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 74998    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 3272     |
# |    fps             | 411      |
# |    time_elapsed    | 2384     |
# |    total_timesteps | 980576   |
# | train/             |          |
# |    actor_loss      | -75.4    |
# |    critic_loss     | 0.757    |
# |    ent_coef        | 0.035    |
# |    ent_coef_loss   | 0.132    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75034    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 3276     |
# |    fps             | 411      |
# |    time_elapsed    | 2385     |
# |    total_timesteps | 981136   |
# | train/             |          |
# |    actor_loss      | -71.1    |
# |    critic_loss     | 3.3      |
# |    ent_coef        | 0.0346   |
# |    ent_coef_loss   | -0.863   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75069    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 3280     |
# |    fps             | 411      |
# |    time_elapsed    | 2387     |
# |    total_timesteps | 982336   |
# | train/             |          |
# |    actor_loss      | -69.5    |
# |    critic_loss     | 5.05     |
# |    ent_coef        | 0.0341   |
# |    ent_coef_loss   | 0.138    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75144    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 3284     |
# |    fps             | 411      |
# |    time_elapsed    | 2389     |
# |    total_timesteps | 983536   |
# | train/             |          |
# |    actor_loss      | -73.5    |
# |    critic_loss     | 2.71     |
# |    ent_coef        | 0.035    |
# |    ent_coef_loss   | 0.304    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75219    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 3288     |
# |    fps             | 411      |
# |    time_elapsed    | 2390     |
# |    total_timesteps | 984048   |
# | train/             |          |
# |    actor_loss      | -71.1    |
# |    critic_loss     | 5.14     |
# |    ent_coef        | 0.0349   |
# |    ent_coef_loss   | 0.114    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75251    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 3292     |
# |    fps             | 411      |
# |    time_elapsed    | 2390     |
# |    total_timesteps | 984576   |
# | train/             |          |
# |    actor_loss      | -72.7    |
# |    critic_loss     | 3.31     |
# |    ent_coef        | 0.0355   |
# |    ent_coef_loss   | 0.0989   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75284    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 3296     |
# |    fps             | 411      |
# |    time_elapsed    | 2392     |
# |    total_timesteps | 985392   |
# | train/             |          |
# |    actor_loss      | -72.4    |
# |    critic_loss     | 9.89     |
# |    ent_coef        | 0.0356   |
# |    ent_coef_loss   | -1.13    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75335    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    episodes        | 3300     |
# |    fps             | 412      |
# |    time_elapsed    | 2394     |
# |    total_timesteps | 986672   |
# | train/             |          |
# |    actor_loss      | -68.1    |
# |    critic_loss     | 1.68     |
# |    ent_coef        | 0.034    |
# |    ent_coef_loss   | -0.841   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75415    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 3304     |
# |    fps             | 412      |
# |    time_elapsed    | 2395     |
# |    total_timesteps | 987232   |
# | train/             |          |
# |    actor_loss      | -68.8    |
# |    critic_loss     | 16.6     |
# |    ent_coef        | 0.0337   |
# |    ent_coef_loss   | 0.345    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75450    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 3308     |
# |    fps             | 412      |
# |    time_elapsed    | 2395     |
# |    total_timesteps | 987728   |
# | train/             |          |
# |    actor_loss      | -71.9    |
# |    critic_loss     | 4.73     |
# |    ent_coef        | 0.0338   |
# |    ent_coef_loss   | -0.623   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75481    |
# ---------------------------------
# Eval num_timesteps=988000, episode_reward=260.04 +/- 10.99
# Episode length: 196.00 +/- 5.40
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 196      |
# |    mean_reward     | 260      |
# | time/              |          |
# |    total_timesteps | 988000   |
# | train/             |          |
# |    actor_loss      | -72.6    |
# |    critic_loss     | 7.97     |
# |    ent_coef        | 0.0337   |
# |    ent_coef_loss   | 0.234    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75498    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    episodes        | 3312     |
# |    fps             | 412      |
# |    time_elapsed    | 2398     |
# |    total_timesteps | 988848   |
# | train/             |          |
# |    actor_loss      | -73.4    |
# |    critic_loss     | 2.15     |
# |    ent_coef        | 0.0339   |
# |    ent_coef_loss   | -1.55    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75551    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 3316     |
# |    fps             | 412      |
# |    time_elapsed    | 2400     |
# |    total_timesteps | 989872   |
# | train/             |          |
# |    actor_loss      | -73.2    |
# |    critic_loss     | 16.2     |
# |    ent_coef        | 0.0337   |
# |    ent_coef_loss   | 0.237    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75615    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 3320     |
# |    fps             | 412      |
# |    time_elapsed    | 2401     |
# |    total_timesteps | 990672   |
# | train/             |          |
# |    actor_loss      | -69.5    |
# |    critic_loss     | 7.73     |
# |    ent_coef        | 0.0341   |
# |    ent_coef_loss   | 0.104    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75665    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    episodes        | 3324     |
# |    fps             | 412      |
# |    time_elapsed    | 2402     |
# |    total_timesteps | 990944   |
# | train/             |          |
# |    actor_loss      | -69.4    |
# |    critic_loss     | 8.06     |
# |    ent_coef        | 0.0344   |
# |    ent_coef_loss   | 0.224    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75682    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    episodes        | 3328     |
# |    fps             | 412      |
# |    time_elapsed    | 2404     |
# |    total_timesteps | 992144   |
# | train/             |          |
# |    actor_loss      | -70.4    |
# |    critic_loss     | 6.07     |
# |    ent_coef        | 0.035    |
# |    ent_coef_loss   | -0.374   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75757    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    episodes        | 3332     |
# |    fps             | 412      |
# |    time_elapsed    | 2405     |
# |    total_timesteps | 992864   |
# | train/             |          |
# |    actor_loss      | -74.4    |
# |    critic_loss     | 4.7      |
# |    ent_coef        | 0.0347   |
# |    ent_coef_loss   | -1.62    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75802    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 3336     |
# |    fps             | 412      |
# |    time_elapsed    | 2406     |
# |    total_timesteps | 993728   |
# | train/             |          |
# |    actor_loss      | -73.5    |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.0335   |
# |    ent_coef_loss   | -0.233   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75856    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 3340     |
# |    fps             | 412      |
# |    time_elapsed    | 2407     |
# |    total_timesteps | 994272   |
# | train/             |          |
# |    actor_loss      | -72.7    |
# |    critic_loss     | 0.756    |
# |    ent_coef        | 0.0331   |
# |    ent_coef_loss   | 0.611    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75890    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 268      |
# | time/              |          |
# |    episodes        | 3344     |
# |    fps             | 413      |
# |    time_elapsed    | 2409     |
# |    total_timesteps | 995184   |
# | train/             |          |
# |    actor_loss      | -71.6    |
# |    critic_loss     | 24       |
# |    ent_coef        | 0.0333   |
# |    ent_coef_loss   | -0.33    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75947    |
# ---------------------------------
# Eval num_timesteps=996000, episode_reward=289.10 +/- 8.75
# Episode length: 224.60 +/- 34.04
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 225      |
# |    mean_reward     | 289      |
# | time/              |          |
# |    total_timesteps | 996000   |
# | train/             |          |
# |    actor_loss      | -73.3    |
# |    critic_loss     | 1.17     |
# |    ent_coef        | 0.0328   |
# |    ent_coef_loss   | -0.455   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 75998    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 268      |
# | time/              |          |
# |    episodes        | 3348     |
# |    fps             | 412      |
# |    time_elapsed    | 2412     |
# |    total_timesteps | 996080   |
# | train/             |          |
# |    actor_loss      | -72.6    |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.0327   |
# |    ent_coef_loss   | -1.11    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 76003    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 3352     |
# |    fps             | 413      |
# |    time_elapsed    | 2412     |
# |    total_timesteps | 996528   |
# | train/             |          |
# |    actor_loss      | -71      |
# |    critic_loss     | 4.17     |
# |    ent_coef        | 0.0326   |
# |    ent_coef_loss   | 0.523    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 76031    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 3356     |
# |    fps             | 413      |
# |    time_elapsed    | 2413     |
# |    total_timesteps | 997328   |
# | train/             |          |
# |    actor_loss      | -72.1    |
# |    critic_loss     | 4.32     |
# |    ent_coef        | 0.034    |
# |    ent_coef_loss   | 1.04     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 76081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    episodes        | 3360     |
# |    fps             | 413      |
# |    time_elapsed    | 2415     |
# |    total_timesteps | 998256   |
# | train/             |          |
# |    actor_loss      | -73.9    |
# |    critic_loss     | 4.29     |
# |    ent_coef        | 0.0364   |
# |    ent_coef_loss   | -0.722   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 76139    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    episodes        | 3364     |
# |    fps             | 413      |
# |    time_elapsed    | 2416     |
# |    total_timesteps | 999280   |
# | train/             |          |
# |    actor_loss      | -70      |
# |    critic_loss     | 8.58     |
# |    ent_coef        | 0.0366   |
# |    ent_coef_loss   | 0.111    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 76203    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 3368     |
# |    fps             | 413      |
# |    time_elapsed    | 2417     |
# |    total_timesteps | 999952   |
# | train/             |          |
# |    actor_loss      | -70.1    |
# |    critic_loss     | 4.41     |
# |    ent_coef        | 0.0359   |
# |    ent_coef_loss   | -0.155   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 76245    |
# ---------------------------------

# %%
model.save("data/policies/LunarLander-v2#tqc#train_best")
del model
